# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/Users/yelderiny/Projects/Dissertation/Data/project-data3.csv')
df.head()
# Out:
#    Unnamed: 0                     name language  pull_requests   size  \
# 0           0        kdn251/interviews     Java             40  24091
# 1           0    crossoverJie/JCSprout     Java             69   1188
# 2           0      linlinjava/litemall     Java             96  24595
# 3           0  winterbe/java8-tutorial     Java             10    149
# 4           0        justauth/JustAuth     Java             25   9554
#
#    contributors   age  contributor_xp1  contributor_xp2  contributor_xp3  \
# 0            28   564            2.020            1.985            1.902
# 1            23   478            3.172            2.960            2.070
# 2            60  1955            4.279            3.977            3.149
# 3            11  1248            2.217            2.098            1.655
# 4            34  1284            1.928            1.850            1.617
#
#    pr_points1  pr_points2  pr_points3
# 0       2.271       2.389       2.377
# ...

# %%
df.boxplot(column=['size', 'age', 'contributor_xp1', 'contributor_xp2', 'contributor_xp3', 'pull_requests', 'contributors'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["size"].mean() - (3 * df["size"].std())
upper_limit = df["size"].mean() + (3 * df["size"].std())

size_outliers = np.where(df["size"]> upper_limit, True,
                np.where(df["size"]< lower_limit, True, False))

df = df.loc[~size_outliers]

df.boxplot(column=['size'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["contributor_xp1"].mean() - (3 * df["contributor_xp1"].std())
upper_limit = df["contributor_xp1"].mean() + (3 * df["contributor_xp1"].std())

contributor_xp_outliers = np.where(df["contributor_xp1"]> upper_limit, True,
                np.where(df["contributor_xp1"]< lower_limit, True, False))

df = df.loc[~contributor_xp_outliers]

df.boxplot(column=['contributor_xp1'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["contributor_xp2"].mean() - (3 * df["contributor_xp2"].std())
upper_limit = df["contributor_xp2"].mean() + (3 * df["contributor_xp2"].std())

contributor_xp_outliers = np.where(df["contributor_xp2"]> upper_limit, True,
                np.where(df["contributor_xp2"]< lower_limit, True, False))

df = df.loc[~contributor_xp_outliers]

df.boxplot(column=['contributor_xp2'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["contributor_xp3"].mean() - (3 * df["contributor_xp3"].std())
upper_limit = df["contributor_xp3"].mean() + (3 * df["contributor_xp3"].std())

contributor_xp_outliers = np.where(df["contributor_xp3"]> upper_limit, True,
                np.where(df["contributor_xp3"]< lower_limit, True, False))

df = df.loc[~contributor_xp_outliers]

df.boxplot(column=['contributor_xp3'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["pull_requests"].mean() - (3 * df["pull_requests"].std())
upper_limit = df["pull_requests"].mean() + (3 * df["pull_requests"].std())

pull_requests_outliers = np.where(df["pull_requests"]> upper_limit, True,
                np.where(df["pull_requests"]< lower_limit, True, False))

df = df.loc[~pull_requests_outliers]

df.boxplot(column=['pull_requests'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["contributors"].mean() - (3 * df["contributors"].std())
upper_limit = df["contributors"].mean() + (3 * df["contributors"].std())

contributors_outliers = np.where(df["contributors"]> upper_limit, True,
                np.where(df["contributors"]< lower_limit, True, False))

df = df.loc[~contributors_outliers]

df.boxplot(column=['contributors'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["pr_points3"].mean() - (3 * df["pr_points3"].std())
upper_limit = df["pr_points3"].mean() + (3 * df["pr_points3"].std())

pr_points3_outliers = np.where(df["pr_points3"]> upper_limit, True,
                np.where(df["pr_points3"]< lower_limit, True, False))

df = df.loc[~pr_points3_outliers]

df.boxplot(column=['pr_points3'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["pr_points2"].mean() - (3 * df["pr_points2"].std())
upper_limit = df["pr_points2"].mean() + (3 * df["pr_points2"].std())

pr_points2_outliers = np.where(df["pr_points2"]> upper_limit, True,
                np.where(df["pr_points2"]< lower_limit, True, False))

df = df.loc[~pr_points2_outliers]

df.boxplot(column=['pr_points2'], figsize=(10,7), rot=45)
plt.show()

# %%
lower_limit = df["pr_points1"].mean() - (3 * df["pr_points1"].std())
upper_limit = df["pr_points1"].mean() + (3 * df["pr_points1"].std())

pr_points1_outliers = np.where(df["pr_points1"]> upper_limit, True,
                np.where(df["pr_points1"]< lower_limit, True, False))

df = df.loc[~pr_points1_outliers]

df.boxplot(column=['pr_points1'], figsize=(10,7), rot=45)
plt.show()

# %%
df.boxplot(column=['size', 'age', 'contributor_xp1', 'contributor_xp2', 'contributor_xp3', 'pull_requests', 'contributors'], figsize=(10,7), rot=45)
plt.show()

# %%
df.to_csv('/Users/yelderiny/Projects/Dissertation/Data/project-data3-outliers-trimmed.csv', index=False)
