# %%
from github import Github
from github import Auth
import pandas as pd

# %%
access_token = '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'  # Freddie's token

auth = Auth.Token(access_token)
g = Github(auth=auth)
login = g.get_user().login

# %%
data_file = '/Users/yelderiny/Projects/Dissertation/Data/project-data3.csv'

# %%
mit = g.search_repositories(query="license:mit")
repos = list(mit)
# Out:
# Request GET /search/repositories?q=license%3Amit&page=10 failed with 403: Forbidden
# Setting next backoff to 60s
# Request GET /search/repositories?q=license%3Amit&page=22 failed with 403: Forbidden
# Setting next backoff to 60s
# Request GET /search/repositories?q=license%3Amit&page=33 failed with 403: Forbidden
# Setting next backoff to 60s

# %%
try:
    existing_data = pd.read_csv(data_file)
except pd.errors.EmptyDataError:
    existing_data = pd.DataFrame()

# %%
equal_weights_pr = [('commits', 0.25), ('additions', 0.25), ('deletions', 0.25), ('changed_files', 0.25)]
weight_split1 = [('commits', 0.2), ('additions', 0.4), ('deletions', 0.3), ('changed_files', 0.1)]
weight_split2 = [('commits', 0.1), ('additions', 0.3), ('deletions', 0.2), ('changed_files', 0.4)]

pr_weight_splits = [equal_weights_pr, weight_split1, weight_split2]

# %%
equal_weights_xp = [('contributions', 0.333), ('followers', 0.333), ('public_repos', 0.333)]
weight_split3 = [('contributions', 0.4), ('followers', 0.3), ('public_repos', 0.3)]
weight_split4 = [('contributions', 0.5), ('followers', 0.35), ('public_repos', 0.15)]

con_xp_splits = [equal_weights_xp, weight_split3, weight_split4]

# %%
def normalize_features(raw_feature, min_value, max_value):
    return 0.5 if min_value == max_value else (raw_feature - min_value) / (max_value - min_value)


def assign_points(obj, dict, pr: bool):
    try:
        weight_splits = pr_weight_splits if pr else con_xp_splits
        return [sum(weight * normalize_features(getattr(obj, key), dict[key][0], dict[key][1]) for key, weight in split)
                for split in weight_splits]
    except Exception as e:
        print(f'Error processing {'pull request' if pr else 'object'} {obj.url}: {e}')
        return [0, 0, 0]


def get_points(objs, my_dict, pr: bool):
    return [round(sum(points[i] for points in (assign_points(obj, my_dict, pr) for obj in objs)), 3) for i in range(3)]

# %%
for repo in repos[500:]:
    try:
        if not existing_data.empty and repo.full_name in existing_data['name'].values:
            print(f'Skipping processing for repo: {repo.full_name}')
            print('-' * 30)
            continue
            
        if repo.language not in ['Java', 'Python', 'C++', 'Go', 'TypeScript', 'Swift']:
            print('Foreign language')
            print(f'Skipping processing for repo: {repo.full_name}')
            print('-' * 30)
            continue

        # Get the repo pull requests
        print(f'Processing {repo.full_name}')

        pr_pages = repo.get_pulls(state='closed', base='master', sort='desc')
        contributor_pages = repo.get_contributors()

        print(f'Number of pull request: {pr_pages.totalCount}')
        print(f'Number of contributors: {contributor_pages.totalCount}')

        if pr_pages.totalCount == 0:
            print(f'No pull requests in this repo')
            print('-' * 30)
            continue

        pull_requests = list(pr_pages)
        contributors = list(contributor_pages)

        pr_features = {
            "commits": (float('inf'), float('-inf')),
            "additions": (float('inf'), float('-inf')),
            "deletions": (float('inf'), float('-inf')),
            "changed_files": (float('inf'), float('-inf'))
        }

        con_features = {
            "contributions": (float('inf'), float('-inf')),
            "followers": (float('inf'), float('-inf')),
            "public_repos": (float('inf'), float('-inf')),
        }
        
        pull_requests = [pr for pr in pull_requests if pr.merged and (pr.additions or pr.deletions)]
        
        for pr in pull_requests:
            for key, value in pr_features.items():
                pr_features[key] = (min(getattr(pr, key), value[0]), max(getattr(pr, key), value[1]))

        print(pr_features)
        print(f'Filtered pull requests: {len(pull_requests)}')
        
        if len(pull_requests) < 5:
            print(f'Not enough pull requests to process')
            print('-' * 30)
            continue
                
        for con in contributors:
            for key, value in con_features.items():
                con_features[key] = (min(getattr(con, key), value[0]), max(getattr(con, key), value[1]))
        
        print(con_features)

        pr_points1, pr_points2, pr_points3 = get_points(pull_requests, pr_features, pr=True)
        xp_points1, xp_points2, xp_points3 = get_points(contributors, con_features, pr=False)

        print(f'Pull Request Points: {pr_points1}, {pr_points2}, {pr_points3}')
        print(f'Contributor Points: {xp_points1}, {xp_points2}, {xp_points3}')

        print('Adding data to dataframe')
        new_data = {
            'name': repo.full_name,
            'language': repo.language,
            'pull_requests': len(pull_requests),
            'size': repo.size,
            'contributors': repo.get_contributors().totalCount,
            'age': (pull_requests[-1].merged_at - repo.created_at).days,
            'contributor_xp1': xp_points1,
            'contributor_xp2': xp_points2,
            'contributor_xp3': xp_points3,
            'pr_points1': pr_points1,
            'pr_points2': pr_points2,
            'pr_points3': pr_points3
        }

        new_entry_df = pd.DataFrame([new_data])
        new_entry_df.to_csv(data_file, mode='a', header=existing_data.empty)

        existing_data = pd.concat([existing_data, new_entry_df], ignore_index=True)

        print('-' * 30)

    except Exception as e:
        print(f'Error processing repo {repo.full_name}: {e}')
        print('-' * 30)
        continue
# Out:
# Foreign language
# Skipping processing for repo: CodeByZach/pace
# ------------------------------
# Skipping processing for repo: eriklindernoren/PyTorch-GAN
# ------------------------------
# Foreign language
# Skipping processing for repo: logspace-ai/langflow
# ------------------------------
# Skipping processing for repo: twintproject/twint
# ------------------------------
# Foreign language
# Skipping processing for repo: jasontaylordev/CleanArchitecture
# ------------------------------
# Foreign language
# Skipping processing for repo: SimulatedGREG/electron-vue
# ------------------------------
# Skipping processing for repo: rrweb-io/rrweb
# ------------------------------
# Foreign language
# Skipping processing for repo: NixOS/nixpkgs
# ------------------------------
# Skipping processing for repo: go-playground/validator
# ------------------------------
# Processing learn-anything/learn-anything.xyz
# Number of pull request: 5
# Number of contributors: 2
# {'commits': (1, 4), 'additions': (14, 51), 'deletions': (0, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Foreign language
# Skipping processing for repo: karpathy/llama2.c
# ------------------------------
# Skipping processing for repo: acdlite/recompose
# ------------------------------
# Foreign language
# Skipping processing for repo: react-native-maps/react-native-maps
# ------------------------------
# Foreign language
# Skipping processing for repo: upptime/upptime
# ------------------------------
# Foreign language
# Skipping processing for repo: facebook/infer
# ------------------------------
# Skipping processing for repo: keystonejs/keystone-classic
# ------------------------------
# Foreign language
# Skipping processing for repo: vernesong/OpenClash
# ------------------------------
# Foreign language
# Skipping processing for repo: mattboldt/typed.js
# ------------------------------
# Foreign language
# Skipping processing for repo: erusev/parsedown
# ------------------------------
# Skipping processing for repo: charmbracelet/glow
# ------------------------------
# Processing microsoft/IoT-For-Beginners
# Number of pull request: 0
# Number of contributors: 67
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: geektutu/7days-golang
# ------------------------------
# Foreign language
# Skipping processing for repo: pqina/filepond
# ------------------------------
# Foreign language
# Skipping processing for repo: twbs/ratchet
# ------------------------------
# Skipping processing for repo: cyrildiagne/ar-cutpaste
# ------------------------------
# Foreign language
# Skipping processing for repo: MaterialDesignInXAML/MaterialDesignInXamlToolkit
# ------------------------------
# Skipping processing for repo: mockito/mockito
# ------------------------------
# Processing infinitered/reactotron
# Number of pull request: 670
# Number of contributors: 120
# {'commits': (1, 4763), 'additions': (0, 64432), 'deletions': (0, 70374), 'changed_files': (1, 786)}
# Filtered pull requests: 548
# {'contributions': (1, 3809), 'followers': (0, 10774), 'public_repos': (0, 38287)}
# Pull Request Points: 5.232, 5.372, 6.229
# Contributor Points: 1.824, 1.801, 1.898
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: skywind3000/kcp
# ------------------------------
# Foreign language
# Skipping processing for repo: leptos-rs/leptos
# ------------------------------
# Processing leon-ai/leon
# Number of pull request: 1
# Number of contributors: 18
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Foreign language
# Skipping processing for repo: bootstrap-vue/bootstrap-vue
# ------------------------------
# Processing stitionai/devika
# Number of pull request: 0
# Number of contributors: 32
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: TheAlgorithms/Go
# ------------------------------
# Skipping processing for repo: microsoft/Bringing-Old-Photos-Back-to-Life
# ------------------------------
# Skipping processing for repo: pyecharts/pyecharts
# ------------------------------
# Skipping processing for repo: dogecoin/dogecoin
# ------------------------------
# Skipping processing for repo: angular-ui/bootstrap
# ------------------------------
# Processing TransformerOptimus/SuperAGI
# Number of pull request: 0
# Number of contributors: 61
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: marcuswestin/WebViewJavascriptBridge
# ------------------------------
# Foreign language
# Skipping processing for repo: hyperium/hyper
# ------------------------------
# Foreign language
# Skipping processing for repo: pure-admin/vue-pure-admin
# ------------------------------
# Foreign language
# Skipping processing for repo: BookStackApp/BookStack
# ------------------------------
# Skipping processing for repo: influxdata/telegraf
# ------------------------------
# Skipping processing for repo: microsoft/nni
# ------------------------------
# Processing ml-explore/mlx
# Number of pull request: 0
# Number of contributors: 88
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: nvim-telescope/telescope.nvim
# ------------------------------
# Foreign language
# Skipping processing for repo: Intervention/image
# ------------------------------
# Skipping processing for repo: xtaci/kcptun
# ------------------------------
# Foreign language
# Skipping processing for repo: philipwalton/flexbugs
# ------------------------------
# Skipping processing for repo: slackhq/nebula
# ------------------------------
# Foreign language
# Skipping processing for repo: graykode/nlp-tutorial
# ------------------------------
# Foreign language
# Skipping processing for repo: filamentphp/filament
# ------------------------------
# Foreign language
# Skipping processing for repo: kettanaito/naming-cheatsheet
# ------------------------------
# Foreign language
# Skipping processing for repo: gollum/gollum
# ------------------------------
# Skipping processing for repo: lgvalle/Material-Animations
# ------------------------------
# Processing charmbracelet/vhs
# Number of pull request: 0
# Number of contributors: 41
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: honojs/hono
# ------------------------------
# Skipping processing for repo: ladjs/supertest
# ------------------------------
# Skipping processing for repo: dcloudio/mui
# ------------------------------
# Foreign language
# Skipping processing for repo: jessfraz/dockerfiles
# ------------------------------
# Skipping processing for repo: tomnomnom/gron
# ------------------------------
# Foreign language
# Skipping processing for repo: Powerlevel9k/powerlevel9k
# ------------------------------
# Skipping processing for repo: polybar/polybar
# ------------------------------
# Skipping processing for repo: louischatriot/nedb
# ------------------------------
# Skipping processing for repo: jimp-dev/jimp
# ------------------------------
# Skipping processing for repo: albumentations-team/albumentations
# ------------------------------
# Foreign language
# Skipping processing for repo: Chuyu-Team/Dism-Multi-language
# ------------------------------
# Processing chartist-js/chartist
# Number of pull request: 7
# Number of contributors: 65
# {'commits': (1, 10), 'additions': (1, 148), 'deletions': (1, 60), 'changed_files': (1, 18)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: piotrwitek/react-redux-typescript-guide
# ------------------------------
# Skipping processing for repo: louischatriot/nedb
# ------------------------------
# Skipping processing for repo: jimp-dev/jimp
# ------------------------------
# Skipping processing for repo: albumentations-team/albumentations
# ------------------------------
# Foreign language
# Skipping processing for repo: Chuyu-Team/Dism-Multi-language
# ------------------------------
# Processing chartist-js/chartist
# Number of pull request: 7
# Number of contributors: 65
# {'commits': (1, 10), 'additions': (1, 148), 'deletions': (1, 60), 'changed_files': (1, 18)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: piotrwitek/react-redux-typescript-guide
# ------------------------------
# Skipping processing for repo: http-party/http-server
# ------------------------------
# Skipping processing for repo: mailhog/MailHog
# ------------------------------
# Skipping processing for repo: schickling/chromeless
# ------------------------------
# Skipping processing for repo: you-dont-need/You-Dont-Need-Momentjs
# ------------------------------
# Foreign language
# Skipping processing for repo: arthurspk/guiadevbrasil
# ------------------------------
# Processing rui314/mold
# Number of pull request: 0
# Number of contributors: 97
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: thephpleague/flysystem
# ------------------------------
# Skipping processing for repo: Semantic-Org/Semantic-UI-React
# ------------------------------
# Skipping processing for repo: FaridSafi/react-native-gifted-chat
# ------------------------------
# Skipping processing for repo: davidshimjs/qrcodejs
# ------------------------------
# Skipping processing for repo: ShangtongZhang/reinforcement-learning-an-introduction
# ------------------------------
# Foreign language
# Skipping processing for repo: filp/whoops
# ------------------------------
# Foreign language
# Skipping processing for repo: cobiwave/simplefolio
# ------------------------------
# Foreign language
# Skipping processing for repo: kitao/pyxel
# ------------------------------
# Skipping processing for repo: marko-js/marko
# ------------------------------
# Skipping processing for repo: Tonejs/Tone.js
# ------------------------------
# Foreign language
# Skipping processing for repo: Universidade-Livre/ciencia-da-computacao
# ------------------------------
# Skipping processing for repo: CodisLabs/codis
# ------------------------------
# Skipping processing for repo: angular/angular-seed
# ------------------------------
# Skipping processing for repo: json-iterator/go
# ------------------------------
# Foreign language
# Skipping processing for repo: philipwalton/solved-by-flexbox
# ------------------------------
# Foreign language
# Skipping processing for repo: wix/react-native-navigation
# ------------------------------
# Skipping processing for repo: sqshq/piggymetrics
# ------------------------------
# Foreign language
# Skipping processing for repo: PHPOffice/PhpSpreadsheet
# ------------------------------
# Foreign language
# Skipping processing for repo: kevinzhow/PNChart
# ------------------------------
# Foreign language
# Skipping processing for repo: dunovank/jupyter-themes
# ------------------------------
# Foreign language
# Skipping processing for repo: pcqpcq/open-source-android-apps
# ------------------------------
# Foreign language
# Skipping processing for repo: sparksuite/simplemde-markdown-editor
# ------------------------------
# Foreign language
# Skipping processing for repo: tennc/webshell
# ------------------------------
# Processing microsoft/wslg
# Number of pull request: 0
# Number of contributors: 36
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: StartBootstrap/startbootstrap-sb-admin-2
# ------------------------------
# Skipping processing for repo: rough-stuff/wired-elements
# ------------------------------
# Skipping processing for repo: newlinedotco/FlappySwift
# ------------------------------
# Foreign language
# Skipping processing for repo: aksakalli/gtop
# ------------------------------
# Skipping processing for repo: liaohuqiu/android-Ultra-Pull-To-Refresh
# ------------------------------
# Foreign language
# Skipping processing for repo: AlloyTeam/Mars
# ------------------------------
# Skipping processing for repo: 99designs/gqlgen
# ------------------------------
# Foreign language
# Skipping processing for repo: swiftmailer/swiftmailer
# ------------------------------
# Skipping processing for repo: openai/spinningup
# ------------------------------
# Foreign language
# Skipping processing for repo: webtorrent/webtorrent-desktop
# ------------------------------
# Skipping processing for repo: retejs/rete
# ------------------------------
# Foreign language
# Skipping processing for repo: VGraupera/1on1-questions
# ------------------------------
# Processing daybrush/moveable
# Number of pull request: 60
# Number of contributors: 36
# {'commits': (1, 36), 'additions': (0, 12951), 'deletions': (0, 6924), 'changed_files': (1, 44)}
# Filtered pull requests: 54
# {'contributions': (1, 1571), 'followers': (0, 1490), 'public_repos': (2, 3987)}
# Pull Request Points: 3.941, 3.314, 4.584
# Contributor Points: 1.907, 1.818, 1.809
# Adding data to dataframe
# ------------------------------
# Processing Nutlope/roomGPT
# Number of pull request: 0
# Number of contributors: 6
# No pull requests in this repo
# ------------------------------
# Processing juice-shop/juice-shop
# Number of pull request: 434
# Number of contributors: 102
# {'commits': (1, 227), 'additions': (1, 2811), 'deletions': (0, 2219), 'changed_files': (1, 116)}
# Filtered pull requests: 119
# {'contributions': (1, 17609), 'followers': (0, 1327), 'public_repos': (0, 38287)}
# Pull Request Points: 7.055, 6.311, 7.74
# Contributor Points: 3.055, 2.864, 3.152
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: Automattic/kue
# ------------------------------
# Foreign language
# Skipping processing for repo: alexanderepstein/Bash-Snippets
# ------------------------------
# Foreign language
# Skipping processing for repo: uncss/uncss
# ------------------------------
# Foreign language
# Skipping processing for repo: resque/resque
# ------------------------------
# Skipping processing for repo: quic-go/quic-go
# ------------------------------
# Foreign language
# Skipping processing for repo: mdbootstrap/material-design-for-bootstrap
# ------------------------------
# Processing stanfordnlp/dspy
# Number of pull request: 0
# Number of contributors: 116
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: olistic/warriorjs
# ------------------------------
# Skipping processing for repo: jackc/pgx
# ------------------------------
# Foreign language
# Skipping processing for repo: swiftmailer/swiftmailer
# ------------------------------
# Skipping processing for repo: openai/spinningup
# ------------------------------
# Foreign language
# Skipping processing for repo: zuiidea/antd-admin
# ------------------------------
# Foreign language
# Skipping processing for repo: webtorrent/webtorrent-desktop
# ------------------------------
# Skipping processing for repo: retejs/rete
# ------------------------------
# Skipping processing for repo: daybrush/moveable
# ------------------------------
# Foreign language
# Skipping processing for repo: foliojs/pdfkit
# ------------------------------
# Processing Nutlope/roomGPT
# Number of pull request: 0
# Number of contributors: 6
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: juice-shop/juice-shop
# ------------------------------
# Skipping processing for repo: Automattic/kue
# ------------------------------
# Foreign language
# Skipping processing for repo: alexanderepstein/Bash-Snippets
# ------------------------------
# Foreign language
# Skipping processing for repo: uncss/uncss
# ------------------------------
# Foreign language
# Skipping processing for repo: resque/resque
# ------------------------------
# Skipping processing for repo: quic-go/quic-go
# ------------------------------
# Foreign language
# Skipping processing for repo: mdbootstrap/material-design-for-bootstrap
# ------------------------------
# Processing stanfordnlp/dspy
# Number of pull request: 0
# Number of contributors: 116
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: olistic/warriorjs
# ------------------------------
# Skipping processing for repo: jackc/pgx
# ------------------------------
# Foreign language
# Skipping processing for repo: cnodejs/nodeclub
# ------------------------------
# Foreign language
# Skipping processing for repo: fgnass/spin.js
# ------------------------------
# Foreign language
# Skipping processing for repo: c3js/c3
# ------------------------------
# Skipping processing for repo: gzc/CLRS
# ------------------------------
# Foreign language
# Skipping processing for repo: phpDocumentor/ReflectionDocBlock
# ------------------------------
# Foreign language
# Skipping processing for repo: MathewSachin/Captura
# ------------------------------
# Foreign language
# Skipping processing for repo: artidoro/qlora
# ------------------------------
# Skipping processing for repo: go-resty/resty
# ------------------------------
# Skipping processing for repo: hacksalot/HackMyResume
# ------------------------------
# Skipping processing for repo: projectdiscovery/subfinder
# ------------------------------
# Skipping processing for repo: vanilla-extract-css/vanilla-extract
# ------------------------------
# Foreign language
# Skipping processing for repo: arasatasaygin/is.js
# ------------------------------
# Foreign language
# Skipping processing for repo: apexcharts/apexcharts.js
# ------------------------------
# Processing youfou/wxpy
# Number of pull request: 8
# Number of contributors: 3
# {'commits': (1, 12), 'additions': (1, 326), 'deletions': (1, 28), 'changed_files': (1, 34)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: myliang/x-spreadsheet
# ------------------------------
# Foreign language
# Skipping processing for repo: hyperium/hyper
# ------------------------------
# Foreign language
# Skipping processing for repo: BookStackApp/BookStack
# ------------------------------
# Foreign language
# Skipping processing for repo: swaywm/sway
# ------------------------------
# Skipping processing for repo: influxdata/telegraf
# ------------------------------
# Skipping processing for repo: microsoft/nni
# ------------------------------
# Processing ml-explore/mlx
# Number of pull request: 0
# Number of contributors: 88
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: nvim-telescope/telescope.nvim
# ------------------------------
# Foreign language
# Skipping processing for repo: cachethq/cachet
# ------------------------------
# Foreign language
# Skipping processing for repo: Azure/azure-quickstart-templates
# ------------------------------
# Foreign language
# Skipping processing for repo: Intervention/image
# ------------------------------
# Foreign language
# Skipping processing for repo: vdumoulin/conv_arithmetic
# ------------------------------
# Skipping processing for repo: xtaci/kcptun
# ------------------------------
# Skipping processing for repo: apollographql/apollo-server
# ------------------------------
# Foreign language
# Skipping processing for repo: philipwalton/flexbugs
# ------------------------------
# Skipping processing for repo: slackhq/nebula
# ------------------------------
# Foreign language
# Skipping processing for repo: graykode/nlp-tutorial
# ------------------------------
# Foreign language
# Skipping processing for repo: filamentphp/filament
# ------------------------------
# Foreign language
# Skipping processing for repo: gollum/gollum
# ------------------------------
# Skipping processing for repo: lgvalle/Material-Animations
# ------------------------------
# Processing charmbracelet/vhs
# Number of pull request: 0
# Number of contributors: 41
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: honojs/hono
# ------------------------------
# Skipping processing for repo: ladjs/supertest
# ------------------------------
# Foreign language
# Skipping processing for repo: pomber/git-history
# ------------------------------
# Skipping processing for repo: zalmoxisus/redux-devtools-extension
# ------------------------------
# Skipping processing for repo: davidsandberg/facenet
# ------------------------------
# Skipping processing for repo: dcloudio/mui
# ------------------------------
# Foreign language
# Skipping processing for repo: jessfraz/dockerfiles
# ------------------------------
# Skipping processing for repo: muaz-khan/WebRTC-Experiment
# ------------------------------
# Skipping processing for repo: redis/jedis
# ------------------------------
# Foreign language
# Skipping processing for repo: tachyons-css/tachyons
# ------------------------------
# Foreign language
# Skipping processing for repo: Idnan/bash-guide
# ------------------------------
# Foreign language
# Skipping processing for repo: aspnetboilerplate/aspnetboilerplate
# ------------------------------
# Skipping processing for repo: luin/medis
# ------------------------------
# Skipping processing for repo: akiran/react-slick
# ------------------------------
# Skipping processing for repo: twpayne/chezmoi
# ------------------------------
# Skipping processing for repo: actualbudget/actual
# ------------------------------
# Skipping processing for repo: zalandoresearch/fashion-mnist
# ------------------------------
# Foreign language
# Skipping processing for repo: dair-ai/ml-visuals
# ------------------------------
# Foreign language
# Skipping processing for repo: sbilly/awesome-security
# ------------------------------
# Skipping processing for repo: nhn/tui.calendar
# ------------------------------
# Skipping processing for repo: ant-design/ant-design-mobile
# ------------------------------
# Skipping processing for repo: rougier/numpy-100
# ------------------------------
# Skipping processing for repo: onivim/oni
# ------------------------------
# Skipping processing for repo: barbajs/barba
# ------------------------------
# Foreign language
# Skipping processing for repo: bang590/JSPatch
# ------------------------------
# Skipping processing for repo: scottjehl/Respond
# ------------------------------
# Skipping processing for repo: summernote/summernote
# ------------------------------
# Foreign language
# Skipping processing for repo: ChrisTitusTech/winutil
# ------------------------------
# Foreign language
# Skipping processing for repo: felangel/bloc
# ------------------------------
# Skipping processing for repo: jxnblk/mdx-deck
# ------------------------------
# Foreign language
# Skipping processing for repo: Ileriayo/markdown-badges
# ------------------------------
# Foreign language
# Skipping processing for repo: microsoft/TypeScript-Node-Starter
# ------------------------------
# Skipping processing for repo: snabbdom/snabbdom
# ------------------------------
# Skipping processing for repo: ptmt/react-native-macos
# ------------------------------
# Skipping processing for repo: mayswind/AriaNg
# ------------------------------
# Skipping processing for repo: DmitryBaranovskiy/raphael
# ------------------------------
# Foreign language
# Skipping processing for repo: AI4Finance-Foundation/FinGPT
# ------------------------------
# Skipping processing for repo: d2-projects/d2-admin
# ------------------------------
# Skipping processing for repo: hotwired/stimulus
# ------------------------------
# Foreign language
# Skipping processing for repo: Perfare/AssetStudio
# ------------------------------
# Foreign language
# Skipping processing for repo: primer/css
# ------------------------------
# Foreign language
# Skipping processing for repo: SVProgressHUD/SVProgressHUD
# ------------------------------
# Skipping processing for repo: Juanpe/SkeletonView
# ------------------------------
# Skipping processing for repo: daimajia/AndroidViewAnimations
# ------------------------------
# Foreign language
# Skipping processing for repo: tmuxinator/tmuxinator
# ------------------------------
# Foreign language
# Skipping processing for repo: lowlighter/metrics
# ------------------------------
# Skipping processing for repo: daimajia/AndroidSwipeLayout
# ------------------------------
# Skipping processing for repo: beetbox/beets
# ------------------------------
# Foreign language
# Skipping processing for repo: h4cc/awesome-elixir
# ------------------------------
# Skipping processing for repo: segmentio/evergreen
# ------------------------------
# Foreign language
# Skipping processing for repo: ramsey/uuid
# ------------------------------
# Skipping processing for repo: gaearon/react-hot-loader
# ------------------------------
# Foreign language
# Skipping processing for repo: laradock/laradock
# ------------------------------
# Skipping processing for repo: react-dates/react-dates
# ------------------------------
# Skipping processing for repo: redis/redis-py
# ------------------------------
# Foreign language
# Skipping processing for repo: cfug/dio
# ------------------------------
# Foreign language
# Skipping processing for repo: picocss/pico
# ------------------------------
# Skipping processing for repo: callstack/react-native-paper
# ------------------------------
# Skipping processing for repo: lokesh/color-thief
# ------------------------------
# Skipping processing for repo: hoffstadt/DearPyGui
# ------------------------------
# Processing resend/react-email
# Number of pull request: 0
# Number of contributors: 114
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: alex000kim/nsfw_data_scraper
# ------------------------------
# Skipping processing for repo: remarkjs/react-markdown
# ------------------------------
# Foreign language
# Skipping processing for repo: UberGuidoZ/Flipper
# ------------------------------
# Foreign language
# Skipping processing for repo: piotrplenik/clean-code-php
# ------------------------------
# Foreign language
# Skipping processing for repo: sinatra/sinatra
# ------------------------------
# Skipping processing for repo: mholt/PapaParse
# ------------------------------
# Skipping processing for repo: fullstorydev/grpcurl
# ------------------------------
# Skipping processing for repo: Manisso/fsociety
# ------------------------------
# Skipping processing for repo: dwarvesf/hidden
# ------------------------------
# Skipping processing for repo: Nozbe/WatermelonDB
# ------------------------------
# Foreign language
# Skipping processing for repo: connors/photon
# ------------------------------
# Foreign language
# Skipping processing for repo: lexfridman/mit-deep-learning
# ------------------------------
# Skipping processing for repo: keplergl/kepler.gl
# ------------------------------
# Foreign language
# Skipping processing for repo: AkashSingh3031/The-Complete-FAANG-Preparation
# ------------------------------
# Skipping processing for repo: typicode/hotel
# ------------------------------
# Foreign language
# Skipping processing for repo: teamcapybara/capybara
# ------------------------------
# Foreign language
# Skipping processing for repo: forkingdog/UITableView-FDTemplateLayoutCell
# ------------------------------
# Foreign language
# Skipping processing for repo: DaveGamble/cJSON
# ------------------------------
# Skipping processing for repo: scottjehl/picturefill
# ------------------------------
# Processing amueller/word_cloud
# Number of pull request: 206
# Number of contributors: 64
# {'commits': (1, 19), 'additions': (0, 10154), 'deletions': (0, 5158), 'changed_files': (1, 30)}
# Filtered pull requests: 134
# {'contributions': (1, 271), 'followers': (0, 10515), 'public_repos': (0, 870)}
# Pull Request Points: 6.266, 4.973, 5.598
# Contributor Points: 4.153, 3.924, 2.821
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: cuixiaorui/mini-vue
# ------------------------------
# Foreign language
# Skipping processing for repo: alcatraz/Alcatraz
# ------------------------------
# Skipping processing for repo: go-task/task
# ------------------------------
# Skipping processing for repo: ds300/patch-package
# ------------------------------
# Foreign language
# Skipping processing for repo: vuematerial/vue-material
# ------------------------------
# Skipping processing for repo: boardgameio/boardgame.io
# ------------------------------
# Processing thumbor/thumbor
# Number of pull request: 650
# Number of contributors: 162
# {'commits': (1, 116), 'additions': (0, 296928), 'deletions': (0, 257742), 'changed_files': (1, 237)}
# Filtered pull requests: 511
# {'contributions': (1, 872), 'followers': (0, 66985), 'public_repos': (0, 38287)}
# Pull Request Points: 4.144, 2.765, 4.65
# Contributor Points: 1.714, 1.778, 1.871
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: ruby-grape/grape
# ------------------------------
# Skipping processing for repo: sfyc23/EverydayWechat
# ------------------------------
# Foreign language
# Skipping processing for repo: doctrine/orm
# ------------------------------
# Skipping processing for repo: getgridea/gridea
# ------------------------------
# Foreign language
# Skipping processing for repo: dotnet/orleans
# ------------------------------
# Skipping processing for repo: adnanh/webhook
# ------------------------------
# Skipping processing for repo: darknessomi/musicbox
# ------------------------------
# Skipping processing for repo: senchalabs/connect
# ------------------------------
# Foreign language
# Skipping processing for repo: jonataslaw/getx
# ------------------------------
# Skipping processing for repo: sqshq/piggymetrics
# ------------------------------
# Foreign language
# Skipping processing for repo: leemunroe/responsive-html-email-template
# ------------------------------
# Skipping processing for repo: gizak/termui
# ------------------------------
# Skipping processing for repo: cubiq/iscroll
# ------------------------------
# Skipping processing for repo: goreleaser/goreleaser
# ------------------------------
# Foreign language
# Skipping processing for repo: othneildrew/Best-README-Template
# ------------------------------
# Skipping processing for repo: auchenberg/volkswagen
# ------------------------------
# Foreign language
# Skipping processing for repo: systemjs/systemjs
# ------------------------------
# Foreign language
# Skipping processing for repo: s-matyukevich/raspberry-pi-os
# ------------------------------
# Skipping processing for repo: apernet/hysteria
# ------------------------------
# Processing microsoft/Swin-Transformer
# Number of pull request: 0
# Number of contributors: 13
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: vitejs/awesome-vite
# ------------------------------
# Skipping processing for repo: lint-staged/lint-staged
# ------------------------------
# Foreign language
# Skipping processing for repo: ellisonleao/magictools
# ------------------------------
# Foreign language
# Skipping processing for repo: Instagram/IGListKit
# ------------------------------
# Skipping processing for repo: surmon-china/vue-awesome-swiper
# ------------------------------
# Foreign language
# Skipping processing for repo: jwagner/smartcrop.js
# ------------------------------
# Processing tiangolo/sqlmodel
# Number of pull request: 0
# Number of contributors: 72
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: newTendermint/awesome-bigdata
# ------------------------------
# Skipping processing for repo: turbolinks/turbolinks
# ------------------------------
# Foreign language
# Skipping processing for repo: sindresorhus/pure
# ------------------------------
# Processing SawyerHood/draw-a-ui
# Number of pull request: 0
# Number of contributors: 4
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: cloudwu/skynet
# ------------------------------
# Skipping processing for repo: nexe/nexe
# ------------------------------
# Skipping processing for repo: facebookarchive/stetho
# ------------------------------
# Foreign language
# Skipping processing for repo: FavioVazquez/ds-cheatsheets
# ------------------------------
# Foreign language
# Skipping processing for repo: capistrano/capistrano
# ------------------------------
# Foreign language
# Skipping processing for repo: blaCCkHatHacEEkr/PENTESTING-BIBLE
# ------------------------------
# Processing theonedev/onedev
# Number of pull request: 9
# Number of contributors: 29
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: fengyuanchen/cropperjs
# ------------------------------
# Foreign language
# Skipping processing for repo: buefy/buefy
# ------------------------------
# Skipping processing for repo: gabrielbull/react-desktop
# ------------------------------
# Skipping processing for repo: daybrush/moveable
# ------------------------------
# Processing chidiwilliams/buzz
# Number of pull request: 0
# Number of contributors: 11
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: ggerganov/ggml
# ------------------------------
# Processing openai/tiktoken
# Number of pull request: 0
# Number of contributors: 15
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: activeadmin/activeadmin
# ------------------------------
# Skipping processing for repo: gwuhaolin/livego
# ------------------------------
# Skipping processing for repo: stephencelis/SQLite.swift
# ------------------------------
# Skipping processing for repo: Automattic/kue
# ------------------------------
# Foreign language
# Skipping processing for repo: krallin/tini
# ------------------------------
# Foreign language
# Skipping processing for repo: Baiyuetribe/paper2gui
# ------------------------------
# Foreign language
# Skipping processing for repo: yandexdataschool/nlp_course
# ------------------------------
# Foreign language
# Skipping processing for repo: microsoft/Windows-universal-samples
# ------------------------------
# Skipping processing for repo: skypjack/entt
# ------------------------------
# Skipping processing for repo: mac-cain13/R.swift
# ------------------------------
# Skipping processing for repo: quic-go/quic-go
# ------------------------------
# Processing react-page/react-page
# Number of pull request: 347
# Number of contributors: 57
# {'commits': (1, 322), 'additions': (0, 104079), 'deletions': (0, 106156), 'changed_files': (1, 561)}
# Filtered pull requests: 259
# {'contributions': (1, 767), 'followers': (0, 1945), 'public_repos': (0, 354)}
# Pull Request Points: 6.318, 5.314, 7.205
# Contributor Points: 4.248, 3.958, 2.776
# Adding data to dataframe
# ------------------------------
# Processing stanfordnlp/dspy
# Number of pull request: 0
# Number of contributors: 116
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: listen1/listen1_desktop
# ------------------------------
# Foreign language
# Skipping processing for repo: messense/aliyundrive-webdav
# ------------------------------
# Foreign language
# Skipping processing for repo: microsoft/mimalloc
# ------------------------------
# Foreign language
# Skipping processing for repo: doctrine/dbal
# ------------------------------
# Skipping processing for repo: danny-avila/LibreChat
# ------------------------------
# Processing facebook/hermes
# Number of pull request: 201
# Number of contributors: 183
# {'commits': (1, 1), 'additions': (0, 0), 'deletions': (6, 17564), 'changed_files': (1, 117)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: gzc/CLRS
# ------------------------------
# Foreign language
# Skipping processing for repo: phpDocumentor/ReflectionDocBlock
# ------------------------------
# Foreign language
# Skipping processing for repo: bmild/nerf
# ------------------------------
# Processing danielmiessler/fabric
# Number of pull request: 0
# Number of contributors: 47
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: microsoft/computervision-recipes
# ------------------------------
# Foreign language
# Skipping processing for repo: Uahh/ToastFish
# ------------------------------
# Skipping processing for repo: coleifer/huey
# ------------------------------
# Foreign language
# Skipping processing for repo: ohmjs/ohm
# ------------------------------
# Processing satori/go.uuid
# Number of pull request: 46
# Number of contributors: 14
# {'commits': (1, 3), 'additions': (1, 99), 'deletions': (0, 14), 'changed_files': (1, 3)}
# Filtered pull requests: 20
# {'contributions': (1, 122), 'followers': (1, 629), 'public_repos': (7, 419)}
# Pull Request Points: 4.031, 4.035, 4.422
# Contributor Points: 3.015, 2.824, 2.368
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: ChilliCream/graphql-platform
# ------------------------------
# Skipping processing for repo: nickoneill/PermissionScope
# ------------------------------
# Processing moranzcw/Computer-Networking-A-Top-Down-Approach-NOTES
# Number of pull request: 17
# Number of contributors: 8
# {'commits': (1, 5), 'additions': (1, 255), 'deletions': (0, 25), 'changed_files': (1, 39)}
# Filtered pull requests: 15
# {'contributions': (1, 108), 'followers': (0, 318), 'public_repos': (11, 87)}
# Pull Request Points: 2.36, 2.311, 2.03
# Contributor Points: 1.779, 1.735, 1.568
# Adding data to dataframe
# ------------------------------
# Processing ThreeDotsLabs/wild-workouts-go-ddd-example
# Number of pull request: 18
# Number of contributors: 8
# {'commits': (1, 4), 'additions': (0, 6466), 'deletions': (0, 4189), 'changed_files': (1, 37)}
# Filtered pull requests: 15
# {'contributions': (1, 34), 'followers': (0, 259), 'public_repos': (4, 513)}
# Pull Request Points: 2.588, 2.329, 2.571
# Contributor Points: 1.792, 1.793, 1.864
# Adding data to dataframe
# ------------------------------
# Processing ReactiveX/RxGo
# Number of pull request: 145
# Number of contributors: 36
# {'commits': (1, 468), 'additions': (0, 32464), 'deletions': (0, 8619), 'changed_files': (1, 143)}
# Filtered pull requests: 76
# {'contributions': (1, 339), 'followers': (0, 5211), 'public_repos': (0, 38287)}
# Pull Request Points: 2.445, 2.174, 2.867
# Contributor Points: 1.396, 1.412, 1.488
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: chrisleekr/binance-trading-bot
# ------------------------------
# Skipping processing for repo: gregmalcolm/python_koans
# ------------------------------
# Processing Shopify/flash-list
# Number of pull request: 0
# Number of contributors: 40
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: tonarino/innernet
# ------------------------------
# Skipping processing for repo: react-native-linear-gradient/react-native-linear-gradient
# ------------------------------
# Processing davidjerleke/embla-carousel
# Number of pull request: 171
# Number of contributors: 34
# {'commits': (1, 47), 'additions': (0, 32859), 'deletions': (0, 14363), 'changed_files': (1, 472)}
# Filtered pull requests: 128
# {'contributions': (1, 506), 'followers': (0, 265), 'public_repos': (0, 148)}
# Pull Request Points: 5.631, 5.281, 5.74
# Contributor Points: 4.539, 4.198, 3.329
# Adding data to dataframe
# ------------------------------
# Processing petyosi/react-virtuoso
# Number of pull request: 201
# Number of contributors: 60
# {'commits': (1, 7), 'additions': (0, 2032), 'deletions': (0, 3450), 'changed_files': (1, 16)}
# Filtered pull requests: 146
# {'contributions': (1, 391), 'followers': (0, 2923), 'public_repos': (0, 320)}
# Pull Request Points: 8.074, 6.071, 8.575
# Contributor Points: 4.469, 4.145, 3.007
# Adding data to dataframe
# ------------------------------
# Processing retorquere/zotero-better-bibtex
# Number of pull request: 513
# Number of contributors: 41
# {'commits': (1, 68), 'additions': (0, 115217), 'deletions': (0, 57892), 'changed_files': (1, 872)}
# Filtered pull requests: 381
# {'contributions': (1, 10730), 'followers': (0, 496), 'public_repos': (0, 337)}
# Pull Request Points: 3.565, 3.161, 2.381
# Contributor Points: 4.638, 4.279, 3.502
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: symfony/polyfill-php72
# ------------------------------
# Foreign language
# Skipping processing for repo: segmentio/analytics.js
# ------------------------------
# Skipping processing for repo: soapyigu/LeetCode-Swift
# ------------------------------
# Foreign language
# Skipping processing for repo: jackmoore/colorbox
# ------------------------------
# Foreign language
# Skipping processing for repo: athityakumar/colorls
# ------------------------------
# Skipping processing for repo: jbeder/yaml-cpp
# ------------------------------
# Foreign language
# Skipping processing for repo: bitpay/bitcore
# ------------------------------
# Processing ethereum/web3.py
# Number of pull request: 1427
# Number of contributors: 227
# {'commits': (1, 41), 'additions': (0, 11180), 'deletions': (0, 5683), 'changed_files': (1, 139)}
# Filtered pull requests: 1218
# {'contributions': (1, 760), 'followers': (0, 4349), 'public_repos': (0, 38287)}
# Pull Request Points: 35.853, 27.932, 34.498
# Contributor Points: 4.514, 4.605, 5.233
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: redux-utilities/flux-standard-action
# ------------------------------
# Processing raycast/extensions
# Number of pull request: 0
# Number of contributors: 457
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: supasate/connected-react-router
# ------------------------------
# Foreign language
# Skipping processing for repo: ethereum/ethereum-org-website
# ------------------------------
# Foreign language
# Skipping processing for repo: coolnameismy/BabyBluetooth
# ------------------------------
# Skipping processing for repo: vipstone/faceai
# ------------------------------
# Foreign language
# Skipping processing for repo: dockur/windows
# ------------------------------
# Foreign language
# Skipping processing for repo: vueComponent/ant-design-vue-pro
# ------------------------------
# Foreign language
# Skipping processing for repo: WenchaoD/FSCalendar
# ------------------------------
# Skipping processing for repo: vercel/micro
# ------------------------------
# Skipping processing for repo: socketio/socket.io-client
# ------------------------------
# Skipping processing for repo: logaretm/vee-validate
# ------------------------------
# Skipping processing for repo: paulmillr/chokidar
# ------------------------------
# Foreign language
# Skipping processing for repo: JamesNK/Newtonsoft.Json
# ------------------------------
# Processing lipangit/JiaoZiVideoPlayer
# Number of pull request: 2
# Number of contributors: 23
# {'commits': (1, 6), 'additions': (23, 49), 'deletions': (1, 17), 'changed_files': (2, 4)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: chimurai/http-proxy-middleware
# ------------------------------
# Foreign language
# Skipping processing for repo: serbanghita/Mobile-Detect
# ------------------------------
# Skipping processing for repo: facebookresearch/ParlAI
# ------------------------------
# Skipping processing for repo: typestack/class-validator
# ------------------------------
# Skipping processing for repo: gleitz/howdoi
# ------------------------------
# Foreign language
# Skipping processing for repo: CompVis/latent-diffusion
# ------------------------------
# Skipping processing for repo: reduxjs/redux-toolkit
# ------------------------------
# Foreign language
# Skipping processing for repo: codota/TabNine
# ------------------------------
# Foreign language
# Skipping processing for repo: oldboyxx/jira_clone
# ------------------------------
# Skipping processing for repo: leecade/react-native-swiper
# ------------------------------
# Skipping processing for repo: FredrikNoren/ungit
# ------------------------------
# Foreign language
# Skipping processing for repo: php-fig/log
# ------------------------------
# Skipping processing for repo: alexfoxy/lax.js
# ------------------------------
# Skipping processing for repo: chiphuyen/stanford-tensorflow-tutorials
# ------------------------------
# Skipping processing for repo: Mintplex-Labs/anything-llm
# ------------------------------
# Skipping processing for repo: dvdzkwsk/react-redux-starter-kit
# ------------------------------
# Skipping processing for repo: chromedp/chromedp
# ------------------------------
# Skipping processing for repo: react-static/react-static
# ------------------------------
# Skipping processing for repo: p0deje/Maccy
# ------------------------------
# Skipping processing for repo: shuding/nextra
# ------------------------------
# Skipping processing for repo: kelektiv/node.bcrypt.js
# ------------------------------
# Foreign language
# Skipping processing for repo: github-changelog-generator/github-changelog-generator
# ------------------------------
# Foreign language
# Skipping processing for repo: symfony/debug
# ------------------------------
# Foreign language
# Skipping processing for repo: HubSpot/odometer
# ------------------------------
# Processing TheLastBen/fast-stable-diffusion
# Number of pull request: 0
# Number of contributors: 19
# No pull requests in this repo
# ------------------------------
# Processing fchollet/deep-learning-models
# Number of pull request: 9
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 2), 'deletions': (1, 2), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: dusty-nv/jetson-inference
# ------------------------------
# Processing zhm-real/PathPlanning
# Number of pull request: 3
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (1, 90), 'deletions': (1, 326), 'changed_files': (1, 5)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: fabiolb/fabio
# ------------------------------
# Foreign language
# Skipping processing for repo: ubuwaits/beautiful-web-type
# ------------------------------
# Skipping processing for repo: SublimeText/Spacegray
# ------------------------------
# Skipping processing for repo: frohoff/ysoserial
# ------------------------------
# Foreign language
# Skipping processing for repo: mrdbourke/machine-learning-roadmap
# ------------------------------
# Foreign language
# Skipping processing for repo: MatthewYork/DateTools
# ------------------------------
# Skipping processing for repo: kazupon/vue-i18n
# ------------------------------
# Skipping processing for repo: go-acme/lego
# ------------------------------
# Skipping processing for repo: lbryio/lbry-sdk
# ------------------------------
# Skipping processing for repo: shekhargulati/52-technologies-in-2016
# ------------------------------
# Foreign language
# Skipping processing for repo: Cysharp/UniTask
# ------------------------------
# Skipping processing for repo: sqlfluff/sqlfluff
# ------------------------------
# Skipping processing for repo: remarkjs/remark
# ------------------------------
# Foreign language
# Skipping processing for repo: CEWendel/SWTableViewCell
# ------------------------------
# Foreign language
# Skipping processing for repo: holman/dotfiles
# ------------------------------
# Skipping processing for repo: xingyizhou/CenterNet
# ------------------------------
# Foreign language
# Skipping processing for repo: FyroxEngine/Fyrox
# ------------------------------
# Foreign language
# Skipping processing for repo: farag2/Sophia-Script-for-Windows
# ------------------------------
# Skipping processing for repo: bchiang7/v4
# ------------------------------
# Skipping processing for repo: es-shims/es5-shim
# ------------------------------
# Skipping processing for repo: deepstreamIO/deepstream.io
# ------------------------------
# Skipping processing for repo: gokcehan/lf
# ------------------------------
# Foreign language
# Skipping processing for repo: adityatelange/hugo-PaperMod
# ------------------------------
# Skipping processing for repo: sass/node-sass
# ------------------------------
# Foreign language
# Skipping processing for repo: spectreconsole/spectre.console
# ------------------------------
# Foreign language
# Skipping processing for repo: rui314/chibicc
# ------------------------------
# Skipping processing for repo: rematch/rematch
# ------------------------------
# Skipping processing for repo: urql-graphql/urql
# ------------------------------
# Skipping processing for repo: ange-yaghi/engine-sim
# ------------------------------
# Foreign language
# Skipping processing for repo: mdo/code-guide
# ------------------------------
# Skipping processing for repo: adrai/flowchart.js
# ------------------------------
# Foreign language
# Skipping processing for repo: leeoniya/uPlot
# ------------------------------
# Foreign language
# Skipping processing for repo: uidotdev/usehooks
# ------------------------------
# Skipping processing for repo: any86/any-rule
# ------------------------------
# Skipping processing for repo: jadore801120/attention-is-all-you-need-pytorch
# ------------------------------
# Foreign language
# Skipping processing for repo: steipete/Aspects
# ------------------------------
# Foreign language
# Skipping processing for repo: svenstaro/genact
# ------------------------------
# Skipping processing for repo: pmndrs/valtio
# ------------------------------
# Foreign language
# Skipping processing for repo: pycaret/pycaret
# ------------------------------
# Skipping processing for repo: react-native-image-picker/react-native-image-picker
# ------------------------------
# Foreign language
# Skipping processing for repo: miniMAC/magic
# ------------------------------
# Skipping processing for repo: baldurk/renderdoc
# ------------------------------
# Foreign language
# Skipping processing for repo: symfony/finder
# ------------------------------
# Foreign language
# Skipping processing for repo: fuck-xuexiqiangguo/Fuck-XueXiQiangGuo
# ------------------------------
# Skipping processing for repo: pahen/madge
# ------------------------------
# Foreign language
# Skipping processing for repo: slackhq/SlackTextViewController
# ------------------------------
# Skipping processing for repo: software-mansion/react-native-reanimated
# ------------------------------
# Processing sourcegraph/conc
# Number of pull request: 0
# Number of contributors: 16
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: 0x7c13/Notepads
# ------------------------------
# Foreign language
# Skipping processing for repo: elkowar/eww
# ------------------------------
# Skipping processing for repo: ggerganov/kbd-audio
# ------------------------------
# Foreign language
# Skipping processing for repo: appbaseio/dejavu
# ------------------------------
# Foreign language
# Skipping processing for repo: kevinzhow/PNChart
# ------------------------------
# Foreign language
# Skipping processing for repo: dunovank/jupyter-themes
# ------------------------------
# Foreign language
# Skipping processing for repo: sparksuite/simplemde-markdown-editor
# ------------------------------
# Foreign language
# Skipping processing for repo: ziahamza/webui-aria2
# ------------------------------
# Skipping processing for repo: oblador/react-native-animatable
# ------------------------------
# Skipping processing for repo: graphql-go/graphql
# ------------------------------
# Skipping processing for repo: swaggo/swag
# ------------------------------
# Foreign language
# Skipping processing for repo: tennc/webshell
# ------------------------------
# Processing microsoft/wslg
# Number of pull request: 0
# Number of contributors: 36
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: StartBootstrap/startbootstrap-sb-admin-2
# ------------------------------
# Skipping processing for repo: FormidableLabs/spectacle
# ------------------------------
# Foreign language
# Skipping processing for repo: trimstray/the-practical-linux-hardening-guide
# ------------------------------
# Skipping processing for repo: temporalio/temporal
# ------------------------------
# Foreign language
# Skipping processing for repo: bobthecow/psysh
# ------------------------------
# Foreign language
# Skipping processing for repo: SaschaWillems/Vulkan
# ------------------------------
# Skipping processing for repo: rough-stuff/wired-elements
# ------------------------------
# Foreign language
# Skipping processing for repo: symfony/console
# ------------------------------
# Skipping processing for repo: nodejs/node-gyp
# ------------------------------
# Foreign language
# Skipping processing for repo: wallabag/wallabag
# ------------------------------
# Skipping processing for repo: liaohuqiu/android-Ultra-Pull-To-Refresh
# ------------------------------
# Foreign language
# Skipping processing for repo: adamwdraper/Numeral-js
# ------------------------------
# Foreign language
# Skipping processing for repo: rgcr/m-cli
# ------------------------------
# Skipping processing for repo: openai/spinningup
# ------------------------------
# Foreign language
# Skipping processing for repo: streamaserver/streama
# ------------------------------
# Skipping processing for repo: soxoj/maigret
# ------------------------------
# Skipping processing for repo: retejs/rete
# ------------------------------
# Skipping processing for repo: captbaritone/webamp
# ------------------------------
# Foreign language
# Skipping processing for repo: astrit/css.gg
# ------------------------------
# Foreign language
# Skipping processing for repo: moovweb/gvm
# ------------------------------
# Foreign language
# Skipping processing for repo: buefy/buefy
# ------------------------------
# Foreign language
# Skipping processing for repo: micro-zoe/micro-app
# ------------------------------
# Foreign language
# Skipping processing for repo: cucumber/cucumber-ruby
# ------------------------------
# Foreign language
# Skipping processing for repo: AR-js-org/AR.js
# ------------------------------
# Processing actions/checkout
# Number of pull request: 92
# Number of contributors: 44
# {'commits': (1, 13), 'additions': (0, 22253), 'deletions': (0, 843), 'changed_files': (1, 33)}
# Filtered pull requests: 61
# {'contributions': (1, 60), 'followers': (0, 7932), 'public_repos': (0, 992)}
# Pull Request Points: 4.097, 3.618, 3.966
# Contributor Points: 2.71, 2.625, 2.321
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: Hashnode/mern-starter
# ------------------------------
# Foreign language
# Skipping processing for repo: jagenjo/webglstudio.js
# ------------------------------
# Foreign language
# Skipping processing for repo: builtbybel/ThisIsWin11
# ------------------------------
# Processing forhappy/Cplusplus-Concurrency-In-Practice
# Number of pull request: 10
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (1, 4), 'deletions': (1, 4), 'changed_files': (1, 1)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Foreign language
# Skipping processing for repo: plotly/falcon
# ------------------------------
# Processing flashlight/flashlight
# Number of pull request: 399
# Number of contributors: 53
# {'commits': (1, 478), 'additions': (3, 374914), 'deletions': (3, 725), 'changed_files': (1, 499)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing vercel/nextjs-subscription-payments
# Number of pull request: 0
# Number of contributors: 24
# No pull requests in this repo
# ------------------------------
# Foreign language
# Skipping processing for repo: dotnet/msbuild
# ------------------------------
# Skipping processing for repo: siteline/swiftui-introspect
# ------------------------------
# Foreign language
# Skipping processing for repo: umpirsky/country-list
# ------------------------------
# Processing taskforcesh/bullmq
# Number of pull request: 1143
# Number of contributors: 131
# {'commits': (1, 110), 'additions': (0, 12769), 'deletions': (0, 11696), 'changed_files': (1, 634)}
# Filtered pull requests: 1016
# {'contributions': (1, 725), 'followers': (0, 1182), 'public_repos': (0, 301)}
# Pull Request Points: 9.158, 9.118, 7.695
# Contributor Points: 11.127, 10.321, 7.555
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: tommoor/tinycon
# ------------------------------
# Foreign language
# Skipping processing for repo: rspec/rspec-rails
# ------------------------------
# Foreign language
# Skipping processing for repo: vakata/jstree
# ------------------------------
# Foreign language
# Skipping processing for repo: lervag/vimtex
# ------------------------------
# Skipping processing for repo: eggswift/ESTabBarController
# ------------------------------
# Processing bubkoo/html-to-image
# Number of pull request: 122
# Number of contributors: 40
# {'commits': (1, 12), 'additions': (1, 144), 'deletions': (0, 8022), 'changed_files': (1, 6)}
# Filtered pull requests: 70
# {'contributions': (1, 192), 'followers': (0, 652), 'public_repos': (0, 201)}
# Pull Request Points: 6.719, 6.504, 8.536
# Contributor Points: 4.591, 4.304, 3.393
# Adding data to dataframe
# ------------------------------
# Foreign language
# Skipping processing for repo: codeigniter4/CodeIgniter4
# ------------------------------
# Skipping processing for repo: Jinxiansen/SwiftUI
# ------------------------------
# Foreign language
# Skipping processing for repo: ldqk/Masuit.Tools
# ------------------------------
# Foreign language
# Skipping processing for repo: aisuhua/restful-api-design-references
# ------------------------------
# Skipping processing for repo: mbadry1/DeepLearning.ai-Summary
# ------------------------------
# Foreign language
# Skipping processing for repo: jagenjo/litegraph.js
# ------------------------------
# Foreign language
# Skipping processing for repo: farhanashrafdev/90DaysOfCyberSecurity
# ------------------------------
# Processing fabian-hiller/valibot
# Number of pull request: 0
# Number of contributors: 66
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: navdeep-G/setup.py
# ------------------------------
