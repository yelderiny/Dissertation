# %%
from github import Github
from github import Auth
import pandas as pd

# %%
access_token = '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'  # Hana's token

auth = Auth.Token(access_token)
g = Github(auth=auth)
login = g.get_user().login

# %%
data_file = '/Users/yelderiny/Projects/Dissertation/Data/project-data3.csv'

# %%
mit = g.search_repositories(query="license:mit")
repos = list(mit)

# %%
try:
    existing_data = pd.read_csv(data_file)
except pd.errors.EmptyDataError:
    existing_data = pd.DataFrame()

# %%
equal_weights_pr = [('commits', 0.25), ('additions', 0.25), ('deletions', 0.25), ('changed_files', 0.25)]
weight_split1 = [('commits', 0.2), ('additions', 0.4), ('deletions', 0.3), ('changed_files', 0.1)]
weight_split2 = [('commits', 0.1), ('additions', 0.3), ('deletions', 0.2), ('changed_files', 0.4)]

pr_weight_splits = [equal_weights_pr, weight_split1, weight_split2]

# %%
equal_weights_xp = [('contributions', 0.333), ('followers', 0.333), ('public_repos', 0.333)]
weight_split3 = [('contributions', 0.4), ('followers', 0.3), ('public_repos', 0.3)]
weight_split4 = [('contributions', 0.5), ('followers', 0.35), ('public_repos', 0.15)]

con_xp_splits = [equal_weights_xp, weight_split3, weight_split4]

# %%
def normalize_features(raw_feature, min_value, max_value):
    return 0.5 if min_value == max_value else (raw_feature - min_value) / (max_value - min_value)


def assign_points(obj, dict, pr: bool):
    try:
        weight_splits = pr_weight_splits if pr else con_xp_splits
        return [sum(weight * normalize_features(getattr(obj, key), dict[key][0], dict[key][1]) for key, weight in split)
                for split in weight_splits]
    except Exception as e:
        print(f'Error processing {'pull request' if pr else 'object'} {obj.url}: {e}')
        return [0, 0, 0]


def get_points(objs, my_dict, pr: bool):
    return [round(sum(points[i] for points in (assign_points(obj, my_dict, pr) for obj in objs)), 3) for i in range(3)]

# %%
for repo in repos[200:]:
    try:
        if not existing_data.empty and repo.full_name in existing_data['name'].values:
            print(f'Skipping processing for repo: {repo.full_name}')
            print('-' * 30)
            continue
            
        if repo.language not in ['Java', 'Python', 'C++', 'Go', 'JavaScript', 'TypeScript', 'Swift']:
            print('Foreign language')
            print(f'Skipping processing for repo: {repo.full_name}')
            print('-' * 30)
            continue

        # Get the repo pull requests
        print(f'Processing {repo.full_name}')

        pr_pages = repo.get_pulls(state='closed', base='master', sort='desc')
        contributor_pages = repo.get_contributors()

        print(f'Number of pull request: {pr_pages.totalCount}')
        print(f'Number of contributors: {contributor_pages.totalCount}')

        if pr_pages.totalCount == 0:
            print(f'No pull requests in this repo')
            print('-' * 30)
            continue

        pull_requests = list(pr_pages)
        contributors = list(contributor_pages)

        pr_features = {
            "commits": (float('inf'), float('-inf')),
            "additions": (float('inf'), float('-inf')),
            "deletions": (float('inf'), float('-inf')),
            "changed_files": (float('inf'), float('-inf'))
        }

        con_features = {
            "contributions": (float('inf'), float('-inf')),
            "followers": (float('inf'), float('-inf')),
            "public_repos": (float('inf'), float('-inf')),
        }
        
        pull_requests = [pr for pr in pull_requests if pr.merged and (pr.additions or pr.deletions)]
        
        for pr in pull_requests:
            for key, value in pr_features.items():
                pr_features[key] = (min(getattr(pr, key), value[0]), max(getattr(pr, key), value[1]))

        print(pr_features)
        print(f'Filtered pull requests: {len(pull_requests)}')
        
        if len(pull_requests) < 5:
            print(f'Not enough pull requests to process')
            print('-' * 30)
            continue
                
        for con in contributors:
            for key, value in con_features.items():
                con_features[key] = (min(getattr(con, key), value[0]), max(getattr(con, key), value[1]))
        
        print(con_features)

        pr_points1, pr_points2, pr_points3 = get_points(pull_requests, pr_features, pr=True)
        xp_points1, xp_points2, xp_points3 = get_points(contributors, con_features, pr=False)

        print(f'Pull Request Points: {pr_points1}, {pr_points2}, {pr_points3}')
        print(f'Contributor Points: {xp_points1}, {xp_points2}, {xp_points3}')

        print('Adding data to dataframe')
        new_data = {
            'name': repo.full_name,
            'language': repo.language,
            'pull_requests': len(pull_requests),
            'size': repo.size,
            'contributors': repo.get_contributors().totalCount,
            'age': (pull_requests[-1].merged_at - repo.created_at).days,
            'contributor_xp1': xp_points1,
            'contributor_xp2': xp_points2,
            'contributor_xp3': xp_points3,
            'pr_points1': pr_points1,
            'pr_points2': pr_points2,
            'pr_points3': pr_points3
        }

        new_entry_df = pd.DataFrame([new_data])
        new_entry_df.to_csv(data_file, mode='a', header=existing_data.empty)

        existing_data = pd.concat([existing_data, new_entry_df], ignore_index=True)

        print('-' * 30)

    except Exception as e:
        print(f'Error processing repo {repo.full_name}: {e}')
        print('-' * 30)
        continue
# Out:
# Skipping processing for repo: kdn251/interviews
# ------------------------------
# Processing xkcoding/spring-boot-demo
# Number of pull request: 26
# Number of contributors: 11
# {'commits': (1, 4), 'additions': (2, 1103), 'deletions': (0, 3), 'changed_files': (1, 15)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing wuyouzhuguli/SpringAll
# Number of pull request: 11
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: crossoverJie/JCSprout
# ------------------------------
# Skipping processing for repo: linlinjava/litemall
# ------------------------------
# Skipping processing for repo: shuzheng/zheng
# ------------------------------
# Skipping processing for repo: winterbe/java8-tutorial
# ------------------------------
# Skipping processing for repo: justauth/JustAuth
# ------------------------------
# Skipping processing for repo: YunaiV/yudao-cloud
# ------------------------------
# Skipping processing for repo: mockito/mockito
# ------------------------------
# Skipping processing for repo: lgvalle/Material-Animations
# ------------------------------
# Skipping processing for repo: gyoogle/tech-interview-for-developer
# ------------------------------
# Skipping processing for repo: sqshq/piggymetrics
# ------------------------------
# Skipping processing for repo: facebookarchive/stetho
# ------------------------------
# Skipping processing for repo: daimajia/AndroidSwipeLayout
# ------------------------------
# Skipping processing for repo: pagehelper/Mybatis-PageHelper
# ------------------------------
# Skipping processing for repo: redis/jedis
# ------------------------------
# Processing H07000223/FlycoTabLayout
# Number of pull request: 7
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: jhy/jsoup
# ------------------------------
# Skipping processing for repo: TooTallNate/Java-WebSocket
# ------------------------------
# Skipping processing for repo: liaohuqiu/android-Ultra-Pull-To-Refresh
# ------------------------------
# Skipping processing for repo: crossoverJie/cim
# ------------------------------
# Skipping processing for repo: ssssssss-team/spider-flow
# ------------------------------
# Processing zfile-dev/zfile
# Number of pull request: 14
# Number of contributors: 5
# {'commits': (1, 1), 'additions': (2, 792), 'deletions': (0, 4), 'changed_files': (1, 13)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: ybq/Android-SpinKit
# ------------------------------
# Skipping processing for repo: react-native-image-picker/react-native-image-picker
# ------------------------------
# Skipping processing for repo: karatelabs/karate
# ------------------------------
# Skipping processing for repo: testcontainers/testcontainers-java
# ------------------------------
# Skipping processing for repo: Bearded-Hen/Android-Bootstrap
# ------------------------------
# Processing geeeeeeeeek/WeChatLuckyMoney
# Number of pull request: 0
# Number of contributors: 7
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: zo0r/react-native-push-notification
# ------------------------------
# Skipping processing for repo: sshahine/JFoenix
# ------------------------------
# Skipping processing for repo: daimajia/NumberProgressBar
# ------------------------------
# Processing graphql-java/graphql-java
# Number of pull request: 1746
# Number of contributors: 211
# {'commits': (1, 166), 'additions': (0, 197707), 'deletions': (0, 7271), 'changed_files': (1, 139)}
# Filtered pull requests: 1435
# {'contributions': (1, 1734), 'followers': (0, 1053), 'public_repos': (0, 38287)}
# Pull Request Points: 22.825, 14.265, 28.208
# Contributor Points: 4.858, 4.597, 5.181
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: prolificinteractive/material-calendarview
# ------------------------------
# Skipping processing for repo: liyifeng1994/ssm
# ------------------------------
# Skipping processing for repo: dmytrodanylyk/circular-progress-button
# ------------------------------
# Processing jpush/aurora-imui
# Number of pull request: 124
# Number of contributors: 15
# {'commits': (1, 31), 'additions': (0, 87450), 'deletions': (0, 70331), 'changed_files': (1, 444)}
# Filtered pull requests: 114
# {'contributions': (1, 537), 'followers': (0, 259), 'public_repos': (6, 168)}
# Pull Request Points: 7.391, 5.888, 5.027
# Contributor Points: 2.768, 2.641, 2.337
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: daimajia/AndroidImageSlider
# ------------------------------
# Processing auth0/java-jwt
# Number of pull request: 300
# Number of contributors: 53
# {'commits': (1, 52), 'additions': (0, 3762), 'deletions': (0, 2428), 'changed_files': (1, 83)}
# Filtered pull requests: 212
# {'contributions': (1, 220), 'followers': (0, 698), 'public_repos': (0, 21310)}
# Pull Request Points: 4.653, 4.294, 4.701
# Contributor Points: 2.478, 2.456, 2.723
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: crazycodeboy/react-native-splash-screen
# ------------------------------
# Skipping processing for repo: scribejava/scribejava
# ------------------------------
# Skipping processing for repo: WeiYe-Jing/datax-web
# ------------------------------
# Processing alibaba/UltraViewPager
# Number of pull request: 3
# Number of contributors: 7
# {'commits': (1, 1), 'additions': (2, 2), 'deletions': (2, 2), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: traex/RippleEffect
# ------------------------------
# Skipping processing for repo: Ramotion/folding-cell-android
# ------------------------------
# Skipping processing for repo: react-native-linear-gradient/react-native-linear-gradient
# ------------------------------
# Skipping processing for repo: citerus/dddsample-core
# ------------------------------
# Skipping processing for repo: j-easy/easy-rules
# ------------------------------
# Skipping processing for repo: lugg/react-native-config
# ------------------------------
# Processing TheoKanning/openai-java
# Number of pull request: 0
# Number of contributors: 32
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: GeyserMC/Geyser
# ------------------------------
# Processing JZ-Darkal/AndroidHttpCapture
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: dreamhead/moco
# ------------------------------
# Processing RedSpider1/concurrent
# Number of pull request: 0
# Number of contributors: 24
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: rubenlagus/TelegramBots
# ------------------------------
# Skipping processing for repo: aporter/coursera-android
# ------------------------------
# Skipping processing for repo: ChadCSong/ShineButton
# ------------------------------
# Skipping processing for repo: 648540858/wvp-GB28181-pro
# ------------------------------
# Processing alibaba/Tangram-Android
# Number of pull request: 3
# Number of contributors: 8
# {'commits': (1, 1), 'additions': (2, 2), 'deletions': (2, 2), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: CameraKit/blurkit-android
# ------------------------------
# Skipping processing for repo: s4kibs4mi/java-developer-roadmap
# ------------------------------
# Skipping processing for repo: lisawray/groupie
# ------------------------------
# Skipping processing for repo: RipMeApp/ripme
# ------------------------------
# Skipping processing for repo: sherxon/AlgoDS
# ------------------------------
# Skipping processing for repo: luojilab/DDComponentForAndroid
# ------------------------------
# Skipping processing for repo: kevinsawicki/http-request
# ------------------------------
# Skipping processing for repo: shekhargulati/99-problems
# ------------------------------
# Skipping processing for repo: Mojang/brigadier
# ------------------------------
# Processing android-notes/Cockroach
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: mbechler/marshalsec
# ------------------------------
# Processing java8/Java8InAction
# Number of pull request: 13
# Number of contributors: 7
# {'commits': (1, 3), 'additions': (2, 733), 'deletions': (0, 169), 'changed_files': (1, 30)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing wix/react-native-notifications
# Number of pull request: 323
# Number of contributors: 78
# {'commits': (1, 74), 'additions': (0, 3453), 'deletions': (0, 1850), 'changed_files': (1, 207)}
# Filtered pull requests: 170
# {'contributions': (1, 196), 'followers': (0, 3509), 'public_repos': (0, 467)}
# Pull Request Points: 4.559, 4.652, 4.556
# Contributor Points: 3.866, 3.683, 2.86
# Adding data to dataframe
# ------------------------------
# Processing amulyakhare/TextDrawable
# Number of pull request: 8
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing rom1v/sndcpy
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing yusugomori/DeepLearning
# Number of pull request: 3
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: szerhusenBC/jwt-spring-security-demo
# ------------------------------
# Processing dmytrodanylyk/android-process-button
# Number of pull request: 6
# Number of contributors: 3
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing lovetuzitong/MultiImageSelector
# Number of pull request: 7
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (4, 4), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing iwgang/CountdownView
# Number of pull request: 5
# Number of contributors: 4
# {'commits': (1, 4), 'additions': (2, 81), 'deletions': (0, 210), 'changed_files': (1, 8)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing jenkinsci/blueocean-plugin
# Number of pull request: 2377
# Number of contributors: 126
# {'commits': (1, 708), 'additions': (0, 50985), 'deletions': (0, 55959), 'changed_files': (1, 1016)}
# Filtered pull requests: 1842
# {'contributions': (1, 564), 'followers': (0, 2143), 'public_repos': (0, 1997)}
# Pull Request Points: 11.278, 10.827, 11.827
# Contributor Points: 7.802, 7.626, 7.092
# Adding data to dataframe
# ------------------------------
# Processing SpecialCyCi/AndroidResideMenu
# Number of pull request: 10
# Number of contributors: 5
# {'commits': (1, 4), 'additions': (3, 268), 'deletions': (0, 387), 'changed_files': (1, 7)}
# Filtered pull requests: 8
# {'contributions': (1, 58), 'followers': (0, 343), 'public_repos': (5, 98)}
# Pull Request Points: 1.751, 1.596, 1.829
# Contributor Points: 1.415, 1.382, 1.331
# Adding data to dataframe
# ------------------------------
# Processing race604/FlyRefresh
# Number of pull request: 2
# Number of contributors: 3
# {'commits': (1, 1), 'additions': (1, 8), 'deletions': (1, 8), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Processing JulienGenoud/android-percent-support-lib-sample
# Number of pull request: 2
# Number of contributors: 1
# {'commits': (1, 1), 'additions': (185, 185), 'deletions': (21, 21), 'changed_files': (5, 5)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing Jzvd/JZVideo
# Number of pull request: 2
# Number of contributors: 44
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: ulisesbocchio/jasypt-spring-boot
# ------------------------------
# Processing oguzbilgener/CircularFloatingActionMenu
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: TangoAgency/material-intro-screen
# ------------------------------
# Skipping processing for repo: andpor/react-native-sqlite-storage
# ------------------------------
# Processing 500px/500px-android-blur
# Number of pull request: 5
# Number of contributors: 3
# {'commits': (1, 9), 'additions': (5, 132), 'deletions': (5, 75), 'changed_files': (4, 16)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing airbnb/native-navigation
# Number of pull request: 83
# Number of contributors: 21
# {'commits': (1, 7), 'additions': (0, 3130), 'deletions': (0, 3042), 'changed_files': (1, 55)}
# Filtered pull requests: 63
# {'contributions': (1, 71), 'followers': (6, 6617), 'public_repos': (2, 38287)}
# Pull Request Points: 5.729, 4.993, 6.642
# Contributor Points: 1.488, 1.488, 1.577
# Adding data to dataframe
# ------------------------------
# Processing rom1v/sndcpy
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: oblador/react-native-keychain
# ------------------------------
# Processing yusugomori/DeepLearning
# Number of pull request: 3
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: szerhusenBC/jwt-spring-security-demo
# ------------------------------
# Processing react-native-google-signin/google-signin
# Number of pull request: 365
# Number of contributors: 96
# {'commits': (1, 21), 'additions': (0, 12320), 'deletions': (0, 13283), 'changed_files': (1, 103)}
# Filtered pull requests: 280
# {'contributions': (1, 195), 'followers': (0, 16757), 'public_repos': (0, 567)}
# Pull Request Points: 7.133, 6.016, 5.986
# Contributor Points: 5.202, 4.857, 3.286
# Adding data to dataframe
# ------------------------------
# Processing dmytrodanylyk/android-process-button
# Number of pull request: 6
# Number of contributors: 3
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing lovetuzitong/MultiImageSelector
# Number of pull request: 7
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (4, 4), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing iwgang/CountdownView
# Number of pull request: 5
# Number of contributors: 4
# {'commits': (1, 4), 'additions': (2, 81), 'deletions': (0, 210), 'changed_files': (1, 8)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: jenkinsci/blueocean-plugin
# ------------------------------
# Skipping processing for repo: SpecialCyCi/AndroidResideMenu
# ------------------------------
# Processing race604/FlyRefresh
# Number of pull request: 2
# Number of contributors: 3
# {'commits': (1, 1), 'additions': (1, 8), 'deletions': (1, 8), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: SalomonBrys/ANR-WatchDog
# ------------------------------
# Skipping processing for repo: Querz/mcaselector
# ------------------------------
# Processing JulienGenoud/android-percent-support-lib-sample
# Number of pull request: 2
# Number of contributors: 1
# {'commits': (1, 1), 'additions': (185, 185), 'deletions': (21, 21), 'changed_files': (5, 5)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing Jzvd/JZVideo
# Number of pull request: 2
# Number of contributors: 44
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: zmxv/react-native-sound
# ------------------------------
# Skipping processing for repo: ulisesbocchio/jasypt-spring-boot
# ------------------------------
# Processing oguzbilgener/CircularFloatingActionMenu
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: TangoAgency/material-intro-screen
# ------------------------------
# Skipping processing for repo: andpor/react-native-sqlite-storage
# ------------------------------
# Processing 500px/500px-android-blur
# Number of pull request: 5
# Number of contributors: 3
# {'commits': (1, 9), 'additions': (5, 132), 'deletions': (5, 75), 'changed_files': (4, 16)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing siyamed/android-shape-imageview
# Number of pull request: 4
# Number of contributors: 3
# {'commits': (1, 2), 'additions': (2, 11), 'deletions': (0, 14), 'changed_files': (1, 5)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing RodneyShag/HackerRank_solutions
# Number of pull request: 33
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: cucumber/cucumber-jvm
# ------------------------------
# Skipping processing for repo: Todd-Davies/ProgressWheel
# ------------------------------
# Skipping processing for repo: chennaione/sugar
# ------------------------------
# Skipping processing for repo: jenkinsci/configuration-as-code-plugin
# ------------------------------
# Skipping processing for repo: esoxjem/MovieGuide
# ------------------------------
# Skipping processing for repo: VerbalExpressions/JavaVerbalExpressions
# ------------------------------
# Skipping processing for repo: igreenwood/SimpleCropView
# ------------------------------
# Skipping processing for repo: ozodrukh/CircularReveal
# ------------------------------
# Processing welk1n/JNDI-Injection-Exploit
# Number of pull request: 2
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing delight-im/Android-AdvancedWebView
# Number of pull request: 18
# Number of contributors: 4
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing Ramotion/cardslider-android
# Number of pull request: 2
# Number of contributors: 9
# {'commits': (1, 11), 'additions': (80, 317), 'deletions': (72, 300), 'changed_files': (9, 19)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Processing huanzi-qch/base-admin
# Number of pull request: 7
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing H07000223/FlycoDialog_Master
# Number of pull request: 2
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (5, 5), 'deletions': (5, 5), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing JingYeoh/FragmentRigger
# Number of pull request: 4
# Number of contributors: 3
# {'commits': (1, 21), 'additions': (3, 4552), 'deletions': (2, 3796), 'changed_files': (1, 80)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing skyfishjy/android-ripple-background
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (7, 7), 'deletions': (5, 5), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing Zhaoss/WeiXinRecordedDemo
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: qos-ch/slf4j
# ------------------------------
# Skipping processing for repo: Notsfsssf/Pix-EzViewer
# ------------------------------
# Processing dmilicic/Android-Clean-Boilerplate
# Number of pull request: 6
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (1, 13), 'deletions': (0, 13), 'changed_files': (1, 1)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: sarxos/webcam-capture
# ------------------------------
# Processing fython/MaterialStepperView
# Number of pull request: 6
# Number of contributors: 5
# {'commits': (1, 2), 'additions': (1, 6), 'deletions': (1, 3), 'changed_files': (1, 1)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing harjot-oberai/MaterialShadows
# Number of pull request: 6
# Number of contributors: 5
# {'commits': (1, 4), 'additions': (1, 342), 'deletions': (0, 107), 'changed_files': (1, 7)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Prototik/HoloEverywhere
# ------------------------------
# Processing gjiazhe/PanoramaImageView
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (0, 0), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing niorgai/StatusBarCompat
# Number of pull request: 3
# Number of contributors: 3
# {'commits': (1, 1), 'additions': (1, 35), 'deletions': (1, 35), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: avjinder/Minimal-Todo
# ------------------------------
# Skipping processing for repo: reneargento/algorithms-sedgewick-wayne
# ------------------------------
# Skipping processing for repo: zcweng/ToggleButton
# ------------------------------
# Processing decaywood/XueQiuSuperSpider
# Number of pull request: 9
# Number of contributors: 3
# {'commits': (1, 2), 'additions': (1, 21), 'deletions': (0, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: thoughtbot/expandable-recycler-view
# ------------------------------
# Processing 1024-lab/smart-admin
# Number of pull request: 35
# Number of contributors: 2
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing Ramotion/android-ui-animation-components-and-libraries
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: Qihoo360/Quicksql
# ------------------------------
# Skipping processing for repo: a466350665/smart-sso
# ------------------------------
# Skipping processing for repo: henninghall/react-native-date-picker
# ------------------------------
# Processing Ramotion/expanding-collection-android
# Number of pull request: 5
# Number of contributors: 10
# {'commits': (1, 23), 'additions': (2, 3274), 'deletions': (0, 78), 'changed_files': (2, 125)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Naccl/NBlog
# ------------------------------
# Skipping processing for repo: nkzawa/socket.io-android-chat
# ------------------------------
# Skipping processing for repo: yale8848/CacheWebView
# ------------------------------
# Skipping processing for repo: shzlw/poli
# ------------------------------
# Processing boycy815/PinchImageView
# Number of pull request: 2
# Number of contributors: 2
# {'commits': (2, 2), 'additions': (24, 902), 'deletions': (214, 2953), 'changed_files': (7, 23)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Processing Yalantis/StarWars.Android
# Number of pull request: 3
# Number of contributors: 3
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: willowtreeapps/Hyperion-Android
# ------------------------------
# Skipping processing for repo: LuckPerms/LuckPerms
# ------------------------------
# Processing Ramotion/circle-menu-android
# Number of pull request: 8
# Number of contributors: 8
# {'commits': (1, 32), 'additions': (1, 1133), 'deletions': (0, 48), 'changed_files': (1, 60)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: friendlyrobotnyc/TinyDancer
# ------------------------------
# Skipping processing for repo: felipecsl/AsymmetricGridView
# ------------------------------
# Processing Ramotion/garland-view-android
# Number of pull request: 1
# Number of contributors: 7
# {'commits': (1, 1), 'additions': (186, 186), 'deletions': (141, 141), 'changed_files': (40, 40)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: react-native-community/react-native-template-typescript
# ------------------------------
# Skipping processing for repo: leibnitz27/cfr
# ------------------------------
# Skipping processing for repo: sucese/android-interview-guide
# ------------------------------
# Skipping processing for repo: RichardWarburton/java-8-lambdas-exercises
# ------------------------------
# Skipping processing for repo: hellokaton/wechat-api
# ------------------------------
# Skipping processing for repo: alibaba/testable-mock
# ------------------------------
# Processing Q42/AndroidScrollingImageView
# Number of pull request: 4
# Number of contributors: 5
# {'commits': (1, 5), 'additions': (2, 106), 'deletions': (2, 61), 'changed_files': (1, 7)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: guyijie1211/JustLive-Android
# ------------------------------
# Processing c0ny1/chunked-coding-converter
# Number of pull request: 2
# Number of contributors: 2
# {'commits': (2, 2), 'additions': (8, 52), 'deletions': (2, 3497), 'changed_files': (39, 46)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: selenide/selenide
# ------------------------------
# Skipping processing for repo: kilim/kilim
# ------------------------------
# Processing radian-software/TerrariaClone
# Number of pull request: 5
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Cleveroad/WaveInApp
# ------------------------------
# Skipping processing for repo: techa03/goodsKill
# ------------------------------
# Skipping processing for repo: felHR85/UsbSerial
# ------------------------------
# Skipping processing for repo: heinrichreimer/material-intro
# ------------------------------
# Skipping processing for repo: zhp8341/flink-streaming-platform-web
# ------------------------------
# Skipping processing for repo: jchambers/pushy
# ------------------------------
# Skipping processing for repo: Java-aid/Hackerrank-Solutions
# ------------------------------
# Skipping processing for repo: 500px/greedo-layout-for-android
# ------------------------------
# Skipping processing for repo: misakuo/3dTagCloudAndroid
# ------------------------------
# Processing traex/ExpandableLayout
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (2, 2), 'additions': (8, 8), 'deletions': (2, 2), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing daimajia/AnimeTaste
# Number of pull request: 4
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing ApplikeySolutions/CosmoCalendar
# Number of pull request: 5
# Number of contributors: 3
# {'commits': (1, 4), 'additions': (2, 112), 'deletions': (2, 54), 'changed_files': (1, 10)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: morenoh149/react-native-contacts
# ------------------------------
# Skipping processing for repo: validator/validator
# ------------------------------
# Skipping processing for repo: omadahealth/LolliPin
# ------------------------------
# Skipping processing for repo: Arello-Mobile/Moxy
# ------------------------------
# Skipping processing for repo: majidgolshadi/Android-Download-Manager-Pro
# ------------------------------
# Skipping processing for repo: BlueMap-Minecraft/BlueMap
# ------------------------------
# Skipping processing for repo: liangfeidotme/AndroidRubberIndicator
# ------------------------------
# Skipping processing for repo: Baeldung/spring-security-registration
# ------------------------------
# Skipping processing for repo: gnembon/fabric-carpet
# ------------------------------
# Processing harjot-oberai/VectorMaster
# Number of pull request: 2
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing gowong/material-sheet-fab
# Number of pull request: 6
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Agontuk/react-native-geolocation-service
# ------------------------------
# Skipping processing for repo: mdgspace/RotatingText
# ------------------------------
# Skipping processing for repo: shekhargulati/java8-the-missing-tutorial
# ------------------------------
# Skipping processing for repo: ocetnik/react-native-background-timer
# ------------------------------
# Skipping processing for repo: dodola/RocooFix
# ------------------------------
# Skipping processing for repo: Piasy/RxAndroidAudio
# ------------------------------
# Skipping processing for repo: bamlab/react-native-image-resizer
# ------------------------------
# Processing badoo/android-weak-handler
# Number of pull request: 2
# Number of contributors: 4
# {'commits': (1, 3), 'additions': (1, 137), 'deletions': (1, 115), 'changed_files': (1, 10)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Processing chthai64/SwipeRevealLayout
# Number of pull request: 9
# Number of contributors: 3
# {'commits': (1, 2), 'additions': (10, 120), 'deletions': (1, 35), 'changed_files': (1, 12)}
# Filtered pull requests: 5
# {'contributions': (1, 74), 'followers': (5, 67), 'public_repos': (3, 26)}
# Pull Request Points: 2.243, 2.159, 2.171
# Contributor Points: 1.018, 1.019, 1.013
# Adding data to dataframe
# ------------------------------
# Processing jrvansuita/MaterialAbout
# Number of pull request: 39
# Number of contributors: 27
# {'commits': (1, 9), 'additions': (1, 1039), 'deletions': (0, 815), 'changed_files': (1, 21)}
# Filtered pull requests: 38
# {'contributions': (1, 127), 'followers': (0, 226), 'public_repos': (1, 140)}
# Pull Request Points: 3.783, 3.154, 4.021
# Contributor Points: 4.072, 3.805, 3.099
# Adding data to dataframe
# ------------------------------
# Processing dmytrodanylyk/folding-plugin
# Number of pull request: 2
# Number of contributors: 1
# {'commits': (4, 4), 'additions': (33, 276), 'deletions': (5, 20), 'changed_files': (6, 8)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Processing nispok/snackbar
# Number of pull request: 52
# Number of contributors: 25
# {'commits': (1, 54), 'additions': (0, 501), 'deletions': (0, 465), 'changed_files': (1, 41)}
# Filtered pull requests: 48
# {'contributions': (1, 69), 'followers': (0, 2008), 'public_repos': (1, 226)}
# Pull Request Points: 3.359, 3.776, 3.902
# Contributor Points: 2.841, 2.723, 2.172
# Adding data to dataframe
# ------------------------------
# Processing dodola/MetaballLoading
# Number of pull request: 2
# Number of contributors: 1
# {'commits': (1, 1), 'additions': (14, 14), 'deletions': (2, 2), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing loda-kun/spring-boot-learning
# Number of pull request: 3
# Number of contributors: 2
# {'commits': (1, 3), 'additions': (21, 215), 'deletions': (0, 1), 'changed_files': (1, 8)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Processing d3vilbug/HackBar
# Number of pull request: 2
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing anvil-ui/anvil
# Number of pull request: 32
# Number of contributors: 14
# {'commits': (1, 26), 'additions': (1, 15693), 'deletions': (0, 20861), 'changed_files': (1, 38)}
# Filtered pull requests: 26
# {'contributions': (1, 289), 'followers': (0, 1914), 'public_repos': (0, 38287)}
# Pull Request Points: 2.153, 1.771, 2.477
# Contributor Points: 1.268, 1.258, 1.304
# Adding data to dataframe
# ------------------------------
# Processing bit4woo/knife
# Number of pull request: 14
# Number of contributors: 3
# {'commits': (1, 12), 'additions': (1, 484), 'deletions': (0, 3107), 'changed_files': (1, 31)}
# Filtered pull requests: 10
# {'contributions': (1, 282), 'followers': (0, 1889), 'public_repos': (0, 113)}
# Pull Request Points: 2.493, 2.443, 2.539
# Contributor Points: 1.041, 1.038, 1.022
# Adding data to dataframe
# ------------------------------
# Processing wgpsec/fofa_viewer
# Number of pull request: 7
# Number of contributors: 8
# {'commits': (1, 2), 'additions': (1, 67), 'deletions': (0, 4), 'changed_files': (1, 2)}
# Filtered pull requests: 6
# {'contributions': (1, 36), 'followers': (0, 2056), 'public_repos': (0, 200)}
# Pull Request Points: 1.275, 1.364, 1.255
# Contributor Points: 1.616, 1.593, 1.449
# Adding data to dataframe
# ------------------------------
# Processing murraco/spring-boot-jwt
# Number of pull request: 10
# Number of contributors: 5
# {'commits': (1, 5), 'additions': (0, 88), 'deletions': (0, 178), 'changed_files': (1, 14)}
# Filtered pull requests: 7
# {'contributions': (1, 34), 'followers': (1, 142), 'public_repos': (6, 60)}
# Pull Request Points: 1.53, 1.546, 1.58
# Contributor Points: 1.265, 1.24, 1.154
# Adding data to dataframe
# ------------------------------
# Processing sleekbyte/tailor
# Number of pull request: 218
# Number of contributors: 5
# {'commits': (1, 85), 'additions': (1, 17597), 'deletions': (0, 17774), 'changed_files': (1, 70)}
# Filtered pull requests: 205
# {'contributions': (1, 559), 'followers': (10, 100), 'public_repos': (5, 76)}
# Pull Request Points: 8.45, 5.807, 9.627
# Contributor Points: 1.633, 1.702, 1.803
# Adding data to dataframe
# ------------------------------
# Processing hehonghui/Colorful
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (2, 2), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing sqlancer/sqlancer
# Number of pull request: 665
# Number of contributors: 46
# {'commits': (1, 25), 'additions': (0, 9339), 'deletions': (0, 2204), 'changed_files': (1, 286)}
# Filtered pull requests: 539
# {'contributions': (1, 1544), 'followers': (0, 1410), 'public_repos': (0, 234)}
# Pull Request Points: 11.571, 10.577, 9.627
# Contributor Points: 4.314, 4.019, 3.05
# Adding data to dataframe
# ------------------------------
# Processing shekhargulati/strman-java
# Number of pull request: 12
# Number of contributors: 7
# {'commits': (1, 13), 'additions': (1, 108), 'deletions': (0, 4), 'changed_files': (1, 4)}
# Filtered pull requests: 11
# {'contributions': (1, 117), 'followers': (5, 1965), 'public_repos': (2, 265)}
# Pull Request Points: 3.281, 3.333, 3.487
# Contributor Points: 1.303, 1.282, 1.181
# Adding data to dataframe
# ------------------------------
# Processing williamyyu/SimpleRatingBar
# Number of pull request: 21
# Number of contributors: 7
# {'commits': (1, 7), 'additions': (1, 224), 'deletions': (0, 183), 'changed_files': (1, 25)}
# Filtered pull requests: 19
# {'contributions': (1, 136), 'followers': (0, 56), 'public_repos': (9, 67)}
# Pull Request Points: 4.347, 4.341, 3.935
# Contributor Points: 2.444, 2.307, 2.141
# Adding data to dataframe
# ------------------------------
# Processing valarchie/AgileBoot-Back-End
# Number of pull request: 0
# Number of contributors: 9
# No pull requests in this repo
# ------------------------------
# Processing jbangdev/jbang
# Number of pull request: 464
# Number of contributors: 85
# {'commits': (1, 24), 'additions': (0, 2615), 'deletions': (0, 4397), 'changed_files': (1, 73)}
# Filtered pull requests: 335
# {'contributions': (1, 898), 'followers': (0, 2011), 'public_repos': (0, 3555)}
# Pull Request Points: 10.165, 8.683, 11.339
# Contributor Points: 4.391, 4.133, 4.016
# Adding data to dataframe
# ------------------------------
# Processing MSPaintIDE/MSPaintIDE
# Number of pull request: 11
# Number of contributors: 10
# {'commits': (1, 15), 'additions': (1, 7749), 'deletions': (0, 2571), 'changed_files': (1, 103)}
# Filtered pull requests: 10
# {'contributions': (1, 254), 'followers': (0, 1300), 'public_repos': (0, 354)}
# Pull Request Points: 1.281, 1.217, 1.195
# Contributor Points: 1.847, 1.77, 1.53
# Adding data to dataframe
# ------------------------------
# Processing waynell/VideoListPlayer
# Number of pull request: 1
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing HackPlan/AndroidCharts
# Number of pull request: 9
# Number of contributors: 6
# {'commits': (1, 4), 'additions': (2, 211), 'deletions': (1, 123), 'changed_files': (1, 7)}
# Filtered pull requests: 6
# {'contributions': (1, 68), 'followers': (0, 197), 'public_repos': (0, 131)}
# Pull Request Points: 1.673, 1.517, 1.848
# Contributor Points: 2.248, 2.131, 1.797
# Adding data to dataframe
# ------------------------------
# Processing ddd-by-examples/factory
# Number of pull request: 18
# Number of contributors: 5
# {'commits': (1, 34), 'additions': (1, 3036), 'deletions': (0, 3265), 'changed_files': (1, 141)}
# Filtered pull requests: 16
# {'contributions': (1, 68), 'followers': (0, 805), 'public_repos': (7, 306)}
# Pull Request Points: 1.746, 1.625, 1.892
# Contributor Points: 1.78, 1.795, 1.894
# Adding data to dataframe
# ------------------------------
# Processing Instagram/ig-json-parser
# Number of pull request: 37
# Number of contributors: 19
# {'commits': (1, 11), 'additions': (0, 518), 'deletions': (0, 262), 'changed_files': (1, 16)}
# Filtered pull requests: 26
# {'contributions': (1, 25), 'followers': (0, 66843), 'public_repos': (0, 206)}
# Pull Request Points: 3.92, 3.379, 4.558
# Contributor Points: 2.976, 3.06, 2.879
# Adding data to dataframe
# ------------------------------
# Processing niniloveyou/StateButton
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (2, 2), 'deletions': (2, 2), 'changed_files': (2, 2)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing limedroid/XDroid
# Number of pull request: 0
# Number of contributors: 2
# No pull requests in this repo
# ------------------------------
# Processing SpongePowered/Mixin
# Number of pull request: 49
# Number of contributors: 23
# {'commits': (1, 8), 'additions': (1, 194), 'deletions': (0, 143), 'changed_files': (1, 14)}
# Filtered pull requests: 12
# {'contributions': (1, 726), 'followers': (0, 604), 'public_repos': (1, 484)}
# Pull Request Points: 1.628, 1.691, 1.778
# Contributor Points: 3.545, 3.298, 3.037
# Adding data to dataframe
# ------------------------------
# Processing WebJournal/journaldev
# Number of pull request: 109
# Number of contributors: 2
# {'commits': (1, 3), 'additions': (46, 741), 'deletions': (0, 0), 'changed_files': (1, 66)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing rnmods/react-native-document-picker
# Number of pull request: 191
# Number of contributors: 70
# {'commits': (1, 20), 'additions': (0, 38253), 'deletions': (0, 17465), 'changed_files': (1, 111)}
# Filtered pull requests: 147
# {'contributions': (1, 118), 'followers': (0, 3717), 'public_repos': (0, 330)}
# Pull Request Points: 3.706, 3.406, 3.219
# Contributor Points: 5.895, 5.581, 4.035
# Adding data to dataframe
# ------------------------------
# Processing developer-shivam/Crescento
# Number of pull request: 3
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing menacher/java-game-server
# Number of pull request: 7
# Number of contributors: 4
# {'commits': (1, 16), 'additions': (1, 775), 'deletions': (1, 461), 'changed_files': (1, 22)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing MegatronKing/NetBare-Android
# Number of pull request: 11
# Number of contributors: 4
# {'commits': (1, 8), 'additions': (1, 263), 'deletions': (0, 175), 'changed_files': (1, 6)}
# Filtered pull requests: 6
# {'contributions': (2, 115), 'followers': (3, 672), 'public_repos': (2, 136)}
# Pull Request Points: 1.628, 1.641, 1.55
# Contributor Points: 1.219, 1.208, 1.143
# Adding data to dataframe
# ------------------------------
# Processing gjiazhe/WaveSideBar
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing wuapnjie/StickerView
# Number of pull request: 11
# Number of contributors: 8
# {'commits': (1, 3), 'additions': (3, 822), 'deletions': (0, 579), 'changed_files': (1, 14)}
# Filtered pull requests: 10
# {'contributions': (1, 62), 'followers': (1, 372), 'public_repos': (0, 95)}
# Pull Request Points: 2.252, 2.264, 2.44
# Contributor Points: 2.025, 1.928, 1.572
# Adding data to dataframe
# ------------------------------
# Processing Zealon159/light-reading-cloud
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Processing revtel/react-native-nfc-manager
# Number of pull request: 63
# Number of contributors: 58
# {'commits': (1, 8), 'additions': (0, 295), 'deletions': (0, 137), 'changed_files': (1, 6)}
# Filtered pull requests: 58
# {'contributions': (1, 447), 'followers': (0, 3984), 'public_repos': (0, 278)}
# Pull Request Points: 8.389, 7.828, 8.873
# Contributor Points: 3.447, 3.225, 2.227
# Adding data to dataframe
# ------------------------------
# Processing android-notes/SwissArmyKnife
# Number of pull request: 1
# Number of contributors: 1
# {'commits': (1, 1), 'additions': (5, 5), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: MSPaintIDE/MSPaintIDE
# ------------------------------
# Processing waynell/VideoListPlayer
# Number of pull request: 1
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Instagram/ig-json-parser
# ------------------------------
# Processing niniloveyou/StateButton
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (2, 2), 'deletions': (2, 2), 'changed_files': (2, 2)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing limedroid/XDroid
# Number of pull request: 0
# Number of contributors: 2
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: SpongePowered/Mixin
# ------------------------------
# Processing WebJournal/journaldev
# Number of pull request: 109
# Number of contributors: 2
# {'commits': (1, 3), 'additions': (46, 741), 'deletions': (0, 0), 'changed_files': (1, 66)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing developer-shivam/Crescento
# Number of pull request: 3
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing ssssssss-team/magic-api
# Number of pull request: 5
# Number of contributors: 21
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing tough1985/RxjavaRetrofitDemo
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Processing simplepeng/SpiderMan
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: MegatronKing/NetBare-Android
# ------------------------------
# Processing gjiazhe/WaveSideBar
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: wuapnjie/StickerView
# ------------------------------
# Processing Zealon159/light-reading-cloud
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: revtel/react-native-nfc-manager
# ------------------------------
# Processing jvm-profiling-tools/honest-profiler
# Number of pull request: 109
# Number of contributors: 23
# {'commits': (1, 164), 'additions': (0, 14383), 'deletions': (0, 1865), 'changed_files': (1, 185)}
# Filtered pull requests: 84
# {'contributions': (1, 287), 'followers': (1, 1157), 'public_repos': (2, 529)}
# Pull Request Points: 2.722, 2.577, 2.791
# Contributor Points: 2.537, 2.481, 2.25
# Adding data to dataframe
# ------------------------------
# Processing pingpongboss/StandOut
# Number of pull request: 8
# Number of contributors: 3
# {'commits': (1, 3), 'additions': (1, 95), 'deletions': (1, 11), 'changed_files': (1, 9)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing RyanFehr/HackerRank
# Number of pull request: 167
# Number of contributors: 9
# Request GET /repos/RyanFehr/HackerRank/pulls/227 failed with 403: Forbidden
# Setting next backoff to 93.048577s
# {'commits': (1, 28), 'additions': (1, 661), 'deletions': (0, 53), 'changed_files': (1, 14)}
# Filtered pull requests: 141
# {'contributions': (1, 514), 'followers': (2, 497), 'public_repos': (7, 284)}
# Pull Request Points: 9.423, 9.683, 10.406
# Contributor Points: 1.361, 1.364, 1.34
# Adding data to dataframe
# ------------------------------
# Processing proyecto26/react-native-inappbrowser
# Number of pull request: 53
# Number of contributors: 39
# {'commits': (1, 21), 'additions': (1, 8219), 'deletions': (0, 6538), 'changed_files': (1, 28)}
# Filtered pull requests: 45
# {'contributions': (1, 300), 'followers': (0, 1397), 'public_repos': (0, 782)}
# Pull Request Points: 3.0, 2.649, 3.049
# Contributor Points: 2.859, 2.693, 2.366
# Adding data to dataframe
# ------------------------------
# Processing harjot-oberai/Croller
# Number of pull request: 9
# Number of contributors: 8
# {'commits': (1, 10), 'additions': (1, 412), 'deletions': (0, 127), 'changed_files': (1, 17)}
# Filtered pull requests: 6
# {'contributions': (1, 43), 'followers': (1, 2024), 'public_repos': (9, 361)}
# Pull Request Points: 1.822, 1.781, 1.827
# Contributor Points: 1.53, 1.518, 1.484
# Adding data to dataframe
# ------------------------------
# Processing microsoft/gctoolkit
# Number of pull request: 0
# Number of contributors: 24
# No pull requests in this repo
# ------------------------------
# Processing asyl/ArcAnimator
# Number of pull request: 5
# Number of contributors: 6
# {'commits': (1, 3), 'additions': (1, 156), 'deletions': (0, 264), 'changed_files': (1, 16)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing bignerdranch/expandable-recycler-view
# Number of pull request: 92
# Number of contributors: 11
# {'commits': (1, 85), 'additions': (0, 2831), 'deletions': (0, 2325), 'changed_files': (1, 80)}
# Filtered pull requests: 68
# {'contributions': (1, 129), 'followers': (2, 566), 'public_repos': (2, 4088)}
# Pull Request Points: 4.617, 4.143, 5.141
# Contributor Points: 1.808, 1.814, 1.958
# Adding data to dataframe
# ------------------------------
# Processing michalchudziak/react-native-geolocation
# Number of pull request: 103
# Number of contributors: 86
# {'commits': (1, 14), 'additions': (1, 13400), 'deletions': (0, 10894), 'changed_files': (1, 111)}
# Filtered pull requests: 88
# {'contributions': (1, 43), 'followers': (0, 9814), 'public_repos': (0, 329)}
# Pull Request Points: 2.445, 2.318, 2.267
# Contributor Points: 7.725, 7.302, 5.523
# Adding data to dataframe
# ------------------------------
# Processing diwi/PixelFlow
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (92, 92), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing thest1/LazyList
# Number of pull request: 7
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing jsquared21/Intro-to-Java-Programming
# Number of pull request: 12
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (3, 143), 'deletions': (0, 3), 'changed_files': (1, 2)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing mpatric/mp3agic
# Number of pull request: 64
# Number of contributors: 20
# {'commits': (1, 6), 'additions': (1, 1493), 'deletions': (0, 172), 'changed_files': (1, 31)}
# Filtered pull requests: 39
# {'contributions': (1, 121), 'followers': (0, 68), 'public_repos': (0, 120)}
# Pull Request Points: 4.805, 4.699, 4.551
# Contributor Points: 3.788, 3.594, 3.23
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: rnmods/react-native-document-picker
# ------------------------------
# Processing whwlsfb/BurpCrypto
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (6, 6), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing developer-shivam/Crescento
# Number of pull request: 3
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing ssssssss-team/magic-api
# Number of pull request: 5
# Number of contributors: 21
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing tough1985/RxjavaRetrofitDemo
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Processing simplepeng/SpiderMan
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Processing menacher/java-game-server
# Number of pull request: 7
# Number of contributors: 4
# {'commits': (1, 16), 'additions': (1, 775), 'deletions': (1, 461), 'changed_files': (1, 22)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: MegatronKing/NetBare-Android
# ------------------------------
# Processing gjiazhe/WaveSideBar
# Number of pull request: 1
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: revtel/react-native-nfc-manager
# ------------------------------
# Processing devunwired/recyclerview-playground
# Number of pull request: 10
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (1, 23), 'deletions': (1, 11), 'changed_files': (1, 3)}
# Filtered pull requests: 6
# {'contributions': (1, 78), 'followers': (3, 2336), 'public_repos': (16, 251)}
# Pull Request Points: 2.436, 2.178, 2.404
# Contributor Points: 1.331, 1.299, 1.238
# Adding data to dataframe
# ------------------------------
# Processing pingpongboss/StandOut
# Number of pull request: 8
# Number of contributors: 3
# {'commits': (1, 3), 'additions': (1, 95), 'deletions': (1, 11), 'changed_files': (1, 9)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing gothinkster/spring-boot-realworld-example-app
# Number of pull request: 32
# Number of contributors: 13
# {'commits': (1, 4), 'additions': (0, 127), 'deletions': (0, 124), 'changed_files': (1, 19)}
# Filtered pull requests: 15
# {'contributions': (1, 87), 'followers': (0, 2269), 'public_repos': (1, 265)}
# Pull Request Points: 3.078, 3.084, 2.964
# Contributor Points: 1.792, 1.728, 1.444
# Adding data to dataframe
# ------------------------------
# Processing yuqirong/CardSwipeLayout
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: proyecto26/react-native-inappbrowser
# ------------------------------
# Processing microsoft/gctoolkit
# Number of pull request: 0
# Number of contributors: 24
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: bignerdranch/expandable-recycler-view
# ------------------------------
# Skipping processing for repo: michalchudziak/react-native-geolocation
# ------------------------------
# Processing jsquared21/Intro-to-Java-Programming
# Number of pull request: 12
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (3, 143), 'deletions': (0, 3), 'changed_files': (1, 2)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing Pkmmte/CircularImageView
# Number of pull request: 7
# Number of contributors: 4
# {'commits': (1, 2), 'additions': (1, 423), 'deletions': (0, 698), 'changed_files': (1, 29)}
# Filtered pull requests: 6
# {'contributions': (1, 21), 'followers': (42, 201), 'public_repos': (18, 171)}
# Pull Request Points: 1.196, 1.104, 1.297
# Contributor Points: 1.719, 1.669, 1.584
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: mpatric/mp3agic
# ------------------------------
# Processing roncoo/roncoo-education
# Number of pull request: 17
# Number of contributors: 11
# {'commits': (1, 2), 'additions': (1, 7), 'deletions': (0, 16), 'changed_files': (1, 1)}
# Filtered pull requests: 8
# {'contributions': (1, 287), 'followers': (0, 19), 'public_repos': (0, 21)}
# Pull Request Points: 1.844, 1.413, 2.275
# Contributor Points: 2.246, 2.195, 1.98
# Adding data to dataframe
# ------------------------------
# Processing zalando/intellij-swagger
# Number of pull request: 206
# Number of contributors: 27
# {'commits': (1, 13), 'additions': (0, 10922), 'deletions': (0, 26079), 'changed_files': (1, 454)}
# Filtered pull requests: 188
# {'contributions': (1, 252), 'followers': (0, 528), 'public_repos': (0, 38287)}
# Pull Request Points: 5.636, 4.974, 4.955
# Contributor Points: 1.671, 1.672, 1.803
# Adding data to dataframe
# ------------------------------
# Processing alexxiyang/shiro-redis
# Number of pull request: 34
# Number of contributors: 12
# {'commits': (1, 5), 'additions': (1, 820), 'deletions': (0, 384), 'changed_files': (1, 11)}
# Filtered pull requests: 17
# {'contributions': (1, 187), 'followers': (0, 177), 'public_repos': (0, 432)}
# Pull Request Points: 3.719, 3.384, 3.696
# Contributor Points: 1.979, 1.89, 1.727
# Adding data to dataframe
# ------------------------------
# Processing thyrlian/AwesomeValidation
# Number of pull request: 18
# Number of contributors: 8
# {'commits': (1, 22), 'additions': (1, 1033), 'deletions': (0, 386), 'changed_files': (1, 30)}
# Filtered pull requests: 11
# {'contributions': (1, 429), 'followers': (0, 2378), 'public_repos': (3, 3954)}
# Pull Request Points: 2.095, 1.841, 2.313
# Contributor Points: 1.093, 1.088, 1.087
# Adding data to dataframe
# ------------------------------
# Processing influxdata/influxdb-java
# Number of pull request: 518
# Number of contributors: 83
# {'commits': (1, 86), 'additions': (0, 4762), 'deletions': (0, 627), 'changed_files': (1, 60)}
# Filtered pull requests: 383
# {'contributions': (1, 490), 'followers': (0, 1795), 'public_repos': (0, 458)}
# Pull Request Points: 6.238, 5.885, 6.583
# Contributor Points: 4.438, 4.221, 3.33
# Adding data to dataframe
# ------------------------------
# Processing davidohayon669/react-native-youtube
# Number of pull request: 93
# Number of contributors: 43
# {'commits': (1, 9), 'additions': (1, 1227), 'deletions': (0, 193), 'changed_files': (1, 20)}
# Filtered pull requests: 58
# {'contributions': (1, 170), 'followers': (0, 7625), 'public_repos': (0, 467)}
# Pull Request Points: 4.632, 4.039, 4.081
# Contributor Points: 3.571, 3.384, 2.521
# Adding data to dataframe
# ------------------------------
# Processing cesardeazevedo/react-native-bottom-sheet-behavior
# Number of pull request: 14
# Number of contributors: 6
# {'commits': (1, 3), 'additions': (1, 3547), 'deletions': (0, 157), 'changed_files': (1, 9)}
# Filtered pull requests: 7
# {'contributions': (1, 197), 'followers': (0, 244), 'public_repos': (0, 52)}
# Pull Request Points: 1.383, 1.26, 1.407
# Contributor Points: 1.87, 1.786, 1.48
# Adding data to dataframe
# ------------------------------
# Processing SpongePowered/SpongeForge
# Number of pull request: 236
# Number of contributors: 63
# {'commits': (1, 14), 'additions': (0, 2952), 'deletions': (0, 2063), 'changed_files': (1, 67)}
# Filtered pull requests: 46
# {'contributions': (1, 958), 'followers': (0, 690), 'public_repos': (1, 484)}
# Pull Request Points: 3.251, 3.256, 3.652
# Contributor Points: 6.814, 6.517, 6.126
# Adding data to dataframe
# ------------------------------
# Processing Mojang/DataFixerUpper
# Number of pull request: 57
# Number of contributors: 15
# {'commits': (1, 96), 'additions': (0, 7308), 'deletions': (0, 1672), 'changed_files': (1, 135)}
# Filtered pull requests: 41
# {'contributions': (1, 104), 'followers': (0, 2103), 'public_repos': (0, 124)}
# Pull Request Points: 2.362, 2.091, 2.528
# Contributor Points: 2.722, 2.643, 2.27
# Adding data to dataframe
# ------------------------------
