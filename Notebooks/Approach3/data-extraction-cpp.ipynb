# %%
from github import Github
from github import Auth
import pandas as pd

# %%
access_token = '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'  # Kareem's token

auth = Auth.Token(access_token)
g = Github(auth=auth)
login = g.get_user().login

# %%
data_file = '/Users/yelderiny/Projects/Dissertation/Data/project-data3.csv'

# %%
cpp = g.search_repositories(query="license:mit size:<50000 language:c++")
repos = list(cpp[:250])

# %%
try:
    existing_data = pd.read_csv(data_file)
except pd.errors.EmptyDataError:
    existing_data = pd.DataFrame()

# %%
equal_weights_pr = [('commits', 0.25), ('additions', 0.25), ('deletions', 0.25), ('changed_files', 0.25)]
weight_split1 = [('commits', 0.2), ('additions', 0.4), ('deletions', 0.3), ('changed_files', 0.1)]
weight_split2 = [('commits', 0.1), ('additions', 0.3), ('deletions', 0.2), ('changed_files', 0.4)]

pr_weight_splits = [equal_weights_pr, weight_split1, weight_split2]

# %%
equal_weights_xp = [('contributions', 0.333), ('followers', 0.333), ('public_repos', 0.333)]
weight_split3 = [('contributions', 0.4), ('followers', 0.3), ('public_repos', 0.3)]
weight_split4 = [('contributions', 0.5), ('followers', 0.35), ('public_repos', 0.15)]

con_xp_splits = [equal_weights_xp, weight_split3, weight_split4]

# %%
def normalize_features(raw_feature, min_value, max_value):
    return 0.5 if min_value == max_value else (raw_feature - min_value) / (max_value - min_value)


def assign_points(obj, dict, pr: bool):
    try:
        weight_splits = pr_weight_splits if pr else con_xp_splits
        return [sum(weight * normalize_features(getattr(obj, key), dict[key][0], dict[key][1]) for key, weight in split)
                for split in weight_splits]
    except Exception as e:
        print(f'Error processing {'pull request' if pr else 'object'} {obj.url}: {e}')
        return [0, 0, 0]


def get_points(objs, my_dict, pr: bool):
    return [round(sum(points[i] for points in (assign_points(obj, my_dict, pr) for obj in objs)), 3) for i in range(3)]

# %%
for repo in repos:
    try:
        if not existing_data.empty and repo.full_name in existing_data['name'].values:
            print(f'Skipping processing for repo: {repo.full_name}')
            print('-' * 30)
            continue

        # Get the repo pull requests
        print(f'Processing {repo.full_name}')

        pr_pages = repo.get_pulls(state='closed', base='master', sort='desc')
        contributor_pages = repo.get_contributors()

        print(f'Number of pull request: {pr_pages.totalCount}')
        print(f'Number of contributors: {contributor_pages.totalCount}')

        if pr_pages.totalCount == 0:
            print(f'No pull requests in this repo')
            print('-' * 30)
            continue

        pull_requests = list(pr_pages)
        contributors = list(contributor_pages)

        pr_features = {
            "commits": (float('inf'), float('-inf')),
            "additions": (float('inf'), float('-inf')),
            "deletions": (float('inf'), float('-inf')),
            "changed_files": (float('inf'), float('-inf'))
        }

        con_features = {
            "contributions": (float('inf'), float('-inf')),
            "followers": (float('inf'), float('-inf')),
            "public_repos": (float('inf'), float('-inf')),
        }
        
        pull_requests = [pr for pr in pull_requests if pr.merged and (pr.additions or pr.deletions)]
        
        for pr in pull_requests:
            for key, value in pr_features.items():
                pr_features[key] = (min(getattr(pr, key), value[0]), max(getattr(pr, key), value[1]))

        print(pr_features)
        print(f'Filtered pull requests: {len(pull_requests)}')
        
        if len(pull_requests) < 5:
            print(f'Not enough pull requests to process')
            print('-' * 30)
            continue
                
        for con in contributors:
            for key, value in con_features.items():
                con_features[key] = (min(getattr(con, key), value[0]), max(getattr(con, key), value[1]))
        
        print(con_features)

        pr_points1, pr_points2, pr_points3 = get_points(pull_requests, pr_features, pr=True)
        xp_points1, xp_points2, xp_points3 = get_points(contributors, con_features, pr=False)

        print(f'Pull Request Points: {pr_points1}, {pr_points2}, {pr_points3}')
        print(f'Contributor Points: {xp_points1}, {xp_points2}, {xp_points3}')

        print('Adding data to dataframe')
        new_data = {
            'name': repo.full_name,
            'language': repo.language,
            'pull_requests': len(pull_requests),
            'size': repo.size,
            'contributors': repo.get_contributors().totalCount,
            'age': (pull_requests[-1].merged_at - repo.created_at).days,
            'contributor_xp1': xp_points1,
            'contributor_xp2': xp_points2,
            'contributor_xp3': xp_points3,
            'pr_points1': pr_points1,
            'pr_points2': pr_points2,
            'pr_points3': pr_points3
        }

        new_entry_df = pd.DataFrame([new_data])
        new_entry_df.to_csv(data_file, mode='a', header=existing_data.empty)

        existing_data = pd.concat([existing_data, new_entry_df], ignore_index=True)

        print('-' * 30)

    except Exception as e:
        print(f'Error processing repo {repo.full_name}: {e}')
        print('-' * 30)
        continue
# Out:
# Processing nomic-ai/gpt4all
# Number of pull request: 0
# Number of contributors: 85
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: ggerganov/llama.cpp
# ------------------------------
# Skipping processing for repo: microsoft/calculator
# ------------------------------
# Skipping processing for repo: cmderdev/cmder
# ------------------------------
# Skipping processing for repo: changkun/modern-cpp-tutorial
# ------------------------------
# Skipping processing for repo: microsoft/winget-cli
# ------------------------------
# Skipping processing for repo: mudler/LocalAI
# ------------------------------
# Skipping processing for repo: facebook/yoga
# ------------------------------
# Skipping processing for repo: microsoft/LightGBM
# ------------------------------
# Skipping processing for repo: polybar/polybar
# ------------------------------
# Processing ml-explore/mlx
# Number of pull request: 0
# Number of contributors: 81
# No pull requests in this repo
# ------------------------------
# Processing rui314/mold
# Number of pull request: 0
# Number of contributors: 97
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: facebook/watchman
# ------------------------------
# Skipping processing for repo: yhirose/cpp-httplib
# ------------------------------
# Skipping processing for repo: drogonframework/drogon
# ------------------------------
# Processing microsoft/wslg
# Number of pull request: 0
# Number of contributors: 37
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: skypjack/entt
# ------------------------------
# Skipping processing for repo: gzc/CLRS
# ------------------------------
# Skipping processing for repo: sass/node-sass
# ------------------------------
# Skipping processing for repo: ange-yaghi/engine-sim
# ------------------------------
# Skipping processing for repo: ggerganov/kbd-audio
# ------------------------------
# Processing kroma-network/tachyon
# Number of pull request: 0
# Number of contributors: 9
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: avast/retdec
# ------------------------------
# Skipping processing for repo: kelektiv/node.bcrypt.js
# ------------------------------
# Processing linyacool/WebServer
# Number of pull request: 5
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (4, 13), 'deletions': (1, 2), 'changed_files': (2, 2)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: erincatto/box2d
# ------------------------------
# Skipping processing for repo: wangyu-/udp2raw
# ------------------------------
# Skipping processing for repo: bblanchon/ArduinoJson
# ------------------------------
# Skipping processing for repo: wang-xinyu/tensorrtx
# ------------------------------
# Skipping processing for repo: tzapu/WiFiManager
# ------------------------------
# Skipping processing for repo: FastLED/FastLED
# ------------------------------
# Processing HackerPoet/NonEuclidean
# Number of pull request: 2
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 1), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing facebook/redex
# Number of pull request: 155
# Number of contributors: 153
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: kdrag0n/safetynet-fix
# ------------------------------
# Processing interpretml/interpret
# Number of pull request: 9
# Number of contributors: 38
# {'commits': (1, 1), 'additions': (3, 3), 'deletions': (10, 10), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: ArthurSonzogni/FTXUI
# ------------------------------
# Skipping processing for repo: butor/blackbird
# ------------------------------
# Skipping processing for repo: duilib/duilib
# ------------------------------
# Processing focus-creative-games/hybridclr
# Number of pull request: 0
# Number of contributors: 6
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: doctest/doctest
# ------------------------------
# Skipping processing for repo: xtaci/algorithms
# ------------------------------
# Processing flashlight/flashlight
# Number of pull request: 399
# Number of contributors: 53
# {'commits': (1, 478), 'additions': (3, 374914), 'deletions': (3, 725), 'changed_files': (1, 499)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Alexays/Waybar
# ------------------------------
# Processing forhappy/Cplusplus-Concurrency-In-Practice
# Number of pull request: 10
# Number of contributors: 4
# {'commits': (1, 1), 'additions': (1, 4), 'deletions': (1, 4), 'changed_files': (1, 1)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: jrouwe/JoltPhysics
# ------------------------------
# Skipping processing for repo: gaoxiang12/slambook2
# ------------------------------
# Skipping processing for repo: justadudewhohacks/opencv4nodejs
# ------------------------------
# Skipping processing for repo: itinance/react-native-fs
# ------------------------------
# Skipping processing for repo: zeux/meshoptimizer
# ------------------------------
# Skipping processing for repo: microsoft/Detours
# ------------------------------
# Skipping processing for repo: TheAssassin/AppImageLauncher
# ------------------------------
# Skipping processing for repo: jbeder/yaml-cpp
# ------------------------------
# Skipping processing for repo: microsoft/SPTAG
# ------------------------------
# Processing wangyu-/UDPspeeder
# Number of pull request: 3
# Number of contributors: 7
# {'commits': (1, 2), 'additions': (1, 69), 'deletions': (1, 68), 'changed_files': (1, 5)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: DarthTon/Blackbone
# ------------------------------
# Skipping processing for repo: kamyu104/LeetCode-Solutions
# ------------------------------
# Skipping processing for repo: peterbraden/node-opencv
# ------------------------------
# Skipping processing for repo: Tatsu-syo/noMeiryoUI
# ------------------------------
# Skipping processing for repo: Neargye/magic_enum
# ------------------------------
# Skipping processing for repo: epezent/implot
# ------------------------------
# Processing R3nzTheCodeGOD/R3nzSkin
# Number of pull request: 0
# Number of contributors: 4
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: lava/matplotlib-cpp
# ------------------------------
# Skipping processing for repo: DDoSolitary/LxRunOffline
# ------------------------------
# Skipping processing for repo: jarro2783/cxxopts
# ------------------------------
# Skipping processing for repo: facebookresearch/StarSpace
# ------------------------------
# Processing JakubVojvoda/design-patterns-cpp
# Number of pull request: 4
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (51, 51), 'deletions': (0, 0), 'changed_files': (5, 5)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing ThePhD/sol2
# Number of pull request: 0
# Number of contributors: 118
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: alandefreitas/matplotplusplus
# ------------------------------
# Processing Sysinternals/ProcMon-for-Linux
# Number of pull request: 0
# Number of contributors: 12
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: blynkkk/blynk-library
# ------------------------------
# Skipping processing for repo: zeux/pugixml
# ------------------------------
# Skipping processing for repo: cppla/ServerStatus
# ------------------------------
# Skipping processing for repo: GothenburgBitFactory/taskwarrior
# ------------------------------
# Skipping processing for repo: knolleary/pubsubclient
# ------------------------------
# Skipping processing for repo: tindy2013/stairspeedtest-reborn
# ------------------------------
# Skipping processing for repo: Chlumsky/msdfgen
# ------------------------------
# Skipping processing for repo: abumq/easyloggingpp
# ------------------------------
# Skipping processing for repo: laverdet/node-fibers
# ------------------------------
# Skipping processing for repo: cmu-db/bustub
# ------------------------------
# Skipping processing for repo: microsoft/verona
# ------------------------------
# Skipping processing for repo: bombela/backward-cpp
# ------------------------------
# Skipping processing for repo: luau-lang/luau
# ------------------------------
# Skipping processing for repo: appjs/appjs
# ------------------------------
# Skipping processing for repo: emilybache/GildedRose-Refactoring-Kata
# ------------------------------
# Processing pezy/LeetCode
# Number of pull request: 8
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (1, 45), 'deletions': (0, 6), 'changed_files': (1, 2)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: ROCm/HIP
# ------------------------------
# Processing microsoft/SEAL
# Number of pull request: 14
# Number of contributors: 37
# {'commits': (1, 2), 'additions': (1, 2), 'deletions': (0, 2), 'changed_files': (1, 2)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: thedmd/imgui-node-editor
# ------------------------------
# Skipping processing for repo: nodejs/nan
# ------------------------------
# Processing facebook/mcrouter
# Number of pull request: 85
# Number of contributors: 160
# {'commits': (1, 1), 'additions': (2, 2), 'deletions': (63, 63), 'changed_files': (4, 4)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Processing callmePicacho/Data-Structres
# Number of pull request: 4
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (21, 45), 'deletions': (0, 47), 'changed_files': (1, 1)}
# Filtered pull requests: 4
# Not enough pull requests to process
# ------------------------------
# Processing CtripMobile/DynamicAPK
# Number of pull request: 1
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing WrBug/dumpDex
# Number of pull request: 0
# Number of contributors: 4
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: rttrorg/rttr
# ------------------------------
# Skipping processing for repo: CedricGuillemet/ImGuizmo
# ------------------------------
# Skipping processing for repo: hyperion-project/hyperion.ng
# ------------------------------
# Skipping processing for repo: sharkdp/dbg-macro
# ------------------------------
# Skipping processing for repo: tiann/FreeReflection
# ------------------------------
# Skipping processing for repo: breach/thrust
# ------------------------------
# Skipping processing for repo: p-ranav/indicators
# ------------------------------
# Skipping processing for repo: ggerganov/imtui
# ------------------------------
# Skipping processing for repo: newsboat/newsboat
# ------------------------------
# Skipping processing for repo: Kobzol/hardware-effects
# ------------------------------
# Processing PetoiCamp/OpenCat
# Number of pull request: 0
# Number of contributors: 13
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: andreasfertig/cppinsights
# ------------------------------
# Skipping processing for repo: banach-space/llvm-tutor
# ------------------------------
# Processing Errichto/youtube
# Number of pull request: 8
# Number of contributors: 3
# {'commits': (1, 1), 'additions': (21, 149), 'deletions': (0, 2), 'changed_files': (1, 1)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Hopson97/MineCraft-One-Week-Challenge
# ------------------------------
# Skipping processing for repo: BehaviorTree/BehaviorTree.CPP
# ------------------------------
# Skipping processing for repo: OpenNMT/CTranslate2
# ------------------------------
# Processing marcj/TypeRunner
# Number of pull request: 4
# Number of contributors: 2
# {'commits': (1, 1), 'additions': (35, 35), 'deletions': (67, 67), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: microsoft/bond
# ------------------------------
# Skipping processing for repo: eidheim/Simple-Web-Server
# ------------------------------
# Skipping processing for repo: picotorrent/picotorrent
# ------------------------------
# Skipping processing for repo: dropbox/json11
# ------------------------------
# Skipping processing for repo: apitrace/apitrace
# ------------------------------
# Skipping processing for repo: yanyiwu/cppjieba
# ------------------------------
# Skipping processing for repo: microsoft/wil
# ------------------------------
# Processing InoriRus/Kyty
# Number of pull request: 0
# Number of contributors: 2
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: Benjamin-Dobell/Heimdall
# ------------------------------
# Skipping processing for repo: picotorrent/picotorrent
# ------------------------------
# Skipping processing for repo: dropbox/json11
# ------------------------------
# Skipping processing for repo: apitrace/apitrace
# ------------------------------
# Skipping processing for repo: ShahjalalShohag/code-library
# ------------------------------
# Skipping processing for repo: microsoft/DirectXTK
# ------------------------------
# Skipping processing for repo: yanyiwu/cppjieba
# ------------------------------
# Skipping processing for repo: microsoft/wil
# ------------------------------
# Processing InoriRus/Kyty
# Number of pull request: 0
# Number of contributors: 2
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: Benjamin-Dobell/Heimdall
# ------------------------------
# Processing li-plus/chatglm.cpp
# Number of pull request: 0
# Number of contributors: 11
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: praydog/REFramework
# ------------------------------
# Skipping processing for repo: mikke89/RmlUi
# ------------------------------
# Skipping processing for repo: jacobdufault/cquery
# ------------------------------
# Skipping processing for repo: leejet/stable-diffusion.cpp
# ------------------------------
# Skipping processing for repo: yuanming-hu/taichi_mpm
# ------------------------------
# Skipping processing for repo: mortbopet/Ripes
# ------------------------------
# Processing tuyoogame/huatuo
# Number of pull request: 0
# Number of contributors: 4
# No pull requests in this repo
# ------------------------------
# Processing mit-biomimetics/Cheetah-Software
# Number of pull request: 3
# Number of contributors: 1
# {'commits': (1, 1), 'additions': (4, 4), 'deletions': (0, 0), 'changed_files': (1, 1)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: rapidfuzz/RapidFuzz
# ------------------------------
# Skipping processing for repo: p-ranav/argparse
# ------------------------------
# Processing wangyu-/tinyfecVPN
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: stevenlovegrove/Pangolin
# ------------------------------
# Skipping processing for repo: johnBuffer/AntSimulator
# ------------------------------
# Skipping processing for repo: socketio/socket.io-client-cpp
# ------------------------------
# Skipping processing for repo: WayfireWM/wayfire
# ------------------------------
# Skipping processing for repo: alecthomas/entityx
# ------------------------------
# Skipping processing for repo: plibither8/2048.cpp
# ------------------------------
# Skipping processing for repo: Presburger/qmc-decoder
# ------------------------------
# Skipping processing for repo: ue4plugins/StreetMap
# ------------------------------
# Processing berthubert/googerteller
# Number of pull request: 0
# Number of contributors: 5
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: kuroni/bongocat-osu
# ------------------------------
# Processing ggerganov/wave-share
# Number of pull request: 0
# Number of contributors: 1
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: thepowersgang/mrustc
# ------------------------------
# Skipping processing for repo: SergiusTheBest/plog
# ------------------------------
# Processing yse/easy_profiler
# Number of pull request: 2
# Number of contributors: 21
# {'commits': (2, 2), 'additions': (24, 24), 'deletions': (5, 5), 'changed_files': (3, 3)}
# Filtered pull requests: 1
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: dpayne/cli-visualizer
# ------------------------------
# Skipping processing for repo: nodejs/node-addon-api
# ------------------------------
# Skipping processing for repo: richgel999/miniz
# ------------------------------
# Skipping processing for repo: Aloshi/EmulationStation
# ------------------------------
# Processing facebookincubator/spectrum
# Number of pull request: 52
# Number of contributors: 41
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: David-Haim/concurrencpp
# ------------------------------
# Processing moudey/Shell
# Number of pull request: 0
# Number of contributors: 17
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: wjwwood/serial
# ------------------------------
# Skipping processing for repo: charto/nbind
# ------------------------------
# Skipping processing for repo: ermig1979/Simd
# ------------------------------
# Processing DarthTon/Xenos
# Number of pull request: 2
# Number of contributors: 3
# {'commits': (1, 2), 'additions': (1, 1), 'deletions': (1, 1), 'changed_files': (1, 1)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: Neargye/nameof
# ------------------------------
# Skipping processing for repo: SpacehuhnTech/WiFiDuck
# ------------------------------
# Skipping processing for repo: ETLCPP/etl
# ------------------------------
# Processing LucidVR/lucidgloves
# Number of pull request: 0
# Number of contributors: 18
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: lucasb-eyer/pydensecrf
# ------------------------------
# Skipping processing for repo: GiacomoLaw/Keylogger
# ------------------------------
# Skipping processing for repo: adafruit/DHT-sensor-library
# ------------------------------
# Skipping processing for repo: Chatterino/chatterino2
# ------------------------------
# Skipping processing for repo: parro-it/libui-node
# ------------------------------
# Skipping processing for repo: joeferner/node-java
# ------------------------------
# Skipping processing for repo: syoyo/tinygltf
# ------------------------------
# Processing bshoshany/thread-pool
# Number of pull request: 39
# Number of contributors: 1
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Processing StudioCherno/Walnut
# Number of pull request: 14
# Number of contributors: 4
# {'commits': (1, 2), 'additions': (2, 6), 'deletions': (1, 9), 'changed_files': (1, 1)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Processing branchseer/DeskGap
# Number of pull request: 6
# Number of contributors: 3
# {'commits': (1, 1), 'additions': (2, 25), 'deletions': (2, 2), 'changed_files': (1, 2)}
# Filtered pull requests: 2
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: polygraphene/ALVR
# ------------------------------
# Skipping processing for repo: jpcy/xatlas
# ------------------------------
# Skipping processing for repo: axstin/rbxfpsunlocker
# ------------------------------
# Skipping processing for repo: unrealcv/unrealcv
# ------------------------------
# Skipping processing for repo: ggerganov/ggwave
# ------------------------------
# Skipping processing for repo: phpv8/v8js
# ------------------------------
# Skipping processing for repo: Nelarius/imnodes
# ------------------------------
# Skipping processing for repo: zeromq/cppzmq
# ------------------------------
# Skipping processing for repo: CedArctic/DigiSpark-Scripts
# ------------------------------
# Skipping processing for repo: simplefoc/Arduino-FOC
# ------------------------------
# Skipping processing for repo: ppwwyyxx/OpenPano
# ------------------------------
# Skipping processing for repo: mike4192/spotMicro
# ------------------------------
# Skipping processing for repo: InteractiveComputerGraphics/PositionBasedDynamics
# ------------------------------
# Skipping processing for repo: prabhuomkar/pytorch-cpp
# ------------------------------
# Skipping processing for repo: ZLMediaKit/ZLToolKit
# ------------------------------
# Skipping processing for repo: p-ranav/tabulate
# ------------------------------
# Skipping processing for repo: qicosmos/cinatra
# ------------------------------
# Skipping processing for repo: skypjack/uvw
# ------------------------------
# Skipping processing for repo: cmu-db/noisepage
# ------------------------------
# Skipping processing for repo: matt-42/silicon
# ------------------------------
# Processing rohit-px2/nvui
# Number of pull request: 0
# Number of contributors: 5
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: TianZerL/Anime4KCPP
# ------------------------------
# Skipping processing for repo: OpenGene/fastp
# ------------------------------
# Skipping processing for repo: FEX-Emu/FEX
# ------------------------------
# Skipping processing for repo: microsoft/ShaderConductor
# ------------------------------
# Skipping processing for repo: 0vercl0k/rp
# ------------------------------
# Skipping processing for repo: microsoft/DirectXTex
# ------------------------------
# Processing sdatkinson/NeuralAmpModelerPlugin
# Number of pull request: 0
# Number of contributors: 8
# No pull requests in this repo
# ------------------------------
# Processing acm-clan/algorithm-stone
# Number of pull request: 0
# Number of contributors: 5
# No pull requests in this repo
# ------------------------------
# Skipping processing for repo: commaai/opendbc
# ------------------------------
# Processing onlytailei/CppRobotics
# Number of pull request: 6
# Number of contributors: 3
# {'commits': (1, 2), 'additions': (1, 105), 'deletions': (0, 2), 'changed_files': (1, 3)}
# Filtered pull requests: 3
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: microsoft/WSL-DistroLauncher
# ------------------------------
# Processing wichtounet/thor-os
# Number of pull request: 1
# Number of contributors: 9
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: whid-injector/WHID
# ------------------------------
# Skipping processing for repo: vimpunk/mio
# ------------------------------
# Skipping processing for repo: TheCruZ/kdmapper
# ------------------------------
# Skipping processing for repo: mtrebi/memory-allocators
# ------------------------------
# Skipping processing for repo: felixguendling/cista
# ------------------------------
# Skipping processing for repo: microsoft/Pyjion
# ------------------------------
# Processing adriengivry/Overload
# Number of pull request: 1
# Number of contributors: 14
# {'commits': (inf, -inf), 'additions': (inf, -inf), 'deletions': (inf, -inf), 'changed_files': (inf, -inf)}
# Filtered pull requests: 0
# Not enough pull requests to process
# ------------------------------
# Skipping processing for repo: nmwsharp/polyscope
# ------------------------------
# Processing microsoft/cppwinrt
# Number of pull request: 458
# Number of contributors: 43
# {'commits': (1, 31), 'additions': (0, 4743), 'deletions': (0, 21342), 'changed_files': (1, 85)}
# Filtered pull requests: 385
# {'contributions': (1, 161), 'followers': (0, 2265), 'public_repos': (0, 300)}
# Pull Request Points: 12.514, 9.775, 11.936
# Contributor Points: 3.703, 3.636, 3.315
# Adding data to dataframe
# ------------------------------
# Processing qicosmos/rest_rpc
# Number of pull request: 35
# Number of contributors: 8
# {'commits': (1, 13), 'additions': (1, 172906), 'deletions': (0, 368), 'changed_files': (1, 660)}
# Filtered pull requests: 27
# {'contributions': (1, 255), 'followers': (0, 1752), 'public_repos': (0, 61)}
# Pull Request Points: 2.267, 2.232, 1.763
# Contributor Points: 1.662, 1.616, 1.377
# Adding data to dataframe
# ------------------------------
# Processing MIT-SPARK/TEASER-plusplus
# Number of pull request: 33
# Number of contributors: 12
# {'commits': (1, 122), 'additions': (1, 17792), 'deletions': (0, 412), 'changed_files': (1, 118)}
# Filtered pull requests: 30
# {'contributions': (1, 37), 'followers': (2, 384), 'public_repos': (6, 105)}
# Pull Request Points: 1.684, 1.628, 1.668
# Contributor Points: 2.398, 2.261, 1.972
# Adding data to dataframe
# ------------------------------
# Processing sandeepmistry/arduino-LoRa
# Number of pull request: 53
# Number of contributors: 21
# {'commits': (1, 18), 'additions': (0, 420), 'deletions': (0, 43), 'changed_files': (1, 7)}
# Filtered pull requests: 35
# {'contributions': (1, 56), 'followers': (0, 1737), 'public_repos': (2, 1467)}
# Pull Request Points: 5.721, 4.743, 6.255
# Contributor Points: 1.915, 1.902, 1.918
# Adding data to dataframe
# ------------------------------
# Processing zhangyuanwei/node-images
# Number of pull request: 21
# Number of contributors: 9
# {'commits': (1, 53), 'additions': (2, 18087), 'deletions': (0, 16717), 'changed_files': (1, 118)}
# Filtered pull requests: 12
# {'contributions': (1, 115), 'followers': (0, 883), 'public_repos': (5, 167)}
# Pull Request Points: 1.168, 1.124, 1.159
# Contributor Points: 2.872, 2.706, 2.189
# Adding data to dataframe
# ------------------------------
# Processing kitesurfer1404/WS2812FX
# Number of pull request: 92
# Number of contributors: 18
# {'commits': (1, 11), 'additions': (1, 4653), 'deletions': (0, 1561), 'changed_files': (1, 27)}
# Filtered pull requests: 73
# {'contributions': (1, 74), 'followers': (1, 1359), 'public_repos': (2, 1467)}
# Pull Request Points: 8.229, 6.614, 8.908
# Contributor Points: 1.812, 1.803, 1.835
# Adding data to dataframe
# ------------------------------
# Processing shader-slang/slang
# Number of pull request: 2778
# Number of contributors: 50
# {'commits': (1, 273), 'additions': (0, 144347), 'deletions': (0, 210791), 'changed_files': (1, 275)}
# Filtered pull requests: 2644
# {'contributions': (1, 1046), 'followers': (0, 1663), 'public_repos': (0, 263)}
# Pull Request Points: 74.159, 52.785, 59.13
# Contributor Points: 3.766, 3.633, 3.078
# Adding data to dataframe
# ------------------------------
# Processing nitroshare/nitroshare-desktop
# Number of pull request: 22
# Number of contributors: 14
# {'commits': (1, 12), 'additions': (1, 859), 'deletions': (0, 50), 'changed_files': (1, 11)}
# Filtered pull requests: 22
# {'contributions': (1, 1302), 'followers': (0, 528), 'public_repos': (6, 38287)}
# Pull Request Points: 2.95, 3.581, 3.241
# Contributor Points: 1.273, 1.249, 1.288
# Adding data to dataframe
# ------------------------------
# Processing mrtazz/restclient-cpp
# Number of pull request: 66
# Number of contributors: 28
# {'commits': (1, 33), 'additions': (0, 24363), 'deletions': (0, 63148), 'changed_files': (1, 37)}
# Filtered pull requests: 47
# {'contributions': (1, 271), 'followers': (0, 428), 'public_repos': (0, 143)}
# Pull Request Points: 2.266, 1.809, 2.48
# Contributor Points: 5.062, 4.672, 3.591
# Adding data to dataframe
# ------------------------------
# Processing SpriteOvO/Telegram-Anti-Revoke
# Number of pull request: 0
# Number of contributors: 3
# No pull requests in this repo
# ------------------------------
# Processing FortySevenEffects/arduino_midi_library
# Number of pull request: 35
# Number of contributors: 15
# {'commits': (1, 30), 'additions': (1, 205), 'deletions': (0, 121), 'changed_files': (1, 4)}
# Filtered pull requests: 22
# {'contributions': (1, 62), 'followers': (0, 684), 'public_repos': (4, 3990)}
# Pull Request Points: 3.455, 2.96, 4.111
# Contributor Points: 1.883, 1.844, 1.884
# Adding data to dataframe
# ------------------------------
# Processing dotnet/llilc
# Number of pull request: 591
# Number of contributors: 27
# {'commits': (1, 70), 'additions': (0, 1048288), 'deletions': (0, 2376683), 'changed_files': (1, 134)}
# Filtered pull requests: 565
# {'contributions': (1, 278), 'followers': (2, 1639), 'public_repos': (1, 38287)}
# Pull Request Points: 8.485, 4.937, 12.271
# Contributor Points: 2.961, 3.069, 3.505
# Adding data to dataframe
# ------------------------------
# Processing wonday/react-native-pdf
# Number of pull request: 150
# Number of contributors: 94
# {'commits': (1, 19), 'additions': (0, 4814), 'deletions': (0, 1738), 'changed_files': (1, 93)}
# Filtered pull requests: 131
# {'contributions': (1, 121), 'followers': (0, 3984), 'public_repos': (0, 278)}
# Pull Request Points: 3.475, 3.132, 3.29
# Contributor Points: 6.892, 6.399, 4.189
# Adding data to dataframe
# ------------------------------
# Processing directvt/vtm
# Number of pull request: 329
# Number of contributors: 6
# {'commits': (1, 222), 'additions': (0, 10465), 'deletions': (0, 6392), 'changed_files': (1, 48)}
# Filtered pull requests: 327
# {'contributions': (1, 3721), 'followers': (1, 27), 'public_repos': (0, 56)}
# Pull Request Points: 22.923, 17.374, 28.238
# Contributor Points: 1.404, 1.365, 1.369
# Adding data to dataframe
# ------------------------------
# Processing electron/rcedit
# Number of pull request: 46
# Number of contributors: 21
# {'commits': (1, 36), 'additions': (1, 550), 'deletions': (0, 495), 'changed_files': (1, 14)}
# Filtered pull requests: 42
# {'contributions': (1, 72), 'followers': (0, 7189), 'public_repos': (0, 311)}
# Pull Request Points: 3.539, 3.446, 3.938
# Contributor Points: 3.233, 3.104, 2.582
# Adding data to dataframe
# ------------------------------
# Processing godot-jolt/godot-jolt
# Number of pull request: 526
# Number of contributors: 2
# {'commits': (1, 31), 'additions': (0, 2184), 'deletions': (0, 837), 'changed_files': (1, 69)}
# Filtered pull requests: 512
# {'contributions': (3, 655), 'followers': (57, 275), 'public_repos': (10, 13)}
# Pull Request Points: 21.81, 20.917, 23.822
# Contributor Points: 0.999, 1.0, 1.0
# Adding data to dataframe
# ------------------------------
# Processing autodiff/autodiff
# Number of pull request: 72
# Number of contributors: 26
# {'commits': (1, 196), 'additions': (1, 22324), 'deletions': (0, 35243), 'changed_files': (1, 110)}
# Filtered pull requests: 69
# {'contributions': (1, 458), 'followers': (0, 1144), 'public_repos': (0, 267)}
# Pull Request Points: 3.174, 2.942, 3.378
# Contributor Points: 3.393, 3.174, 2.474
# Adding data to dataframe
# ------------------------------
# Processing pantor/inja
# Number of pull request: 99
# Number of contributors: 41
# {'commits': (1, 34), 'additions': (1, 16349), 'deletions': (0, 22934), 'changed_files': (1, 77)}
# Filtered pull requests: 72
# {'contributions': (1, 371), 'followers': (0, 905), 'public_repos': (1, 298)}
# Pull Request Points: 3.292, 2.983, 3.024
# Contributor Points: 3.813, 3.544, 2.945
# Adding data to dataframe
# ------------------------------
# Processing juj/fbcp-ili9341
# Number of pull request: 20
# Number of contributors: 13
# {'commits': (1, 9), 'additions': (1, 204), 'deletions': (0, 4), 'changed_files': (1, 6)}
# Filtered pull requests: 13
# {'contributions': (1, 333), 'followers': (0, 408), 'public_repos': (7, 145)}
# Pull Request Points: 3.126, 2.942, 3.371
# Contributor Points: 2.497, 2.351, 1.829
# Adding data to dataframe
# ------------------------------
# Skipping processing for repo: juj/fbcp-ili9341
# ------------------------------
# Processing tdenniston/bish
# Number of pull request: 21
# Number of contributors: 11
# {'commits': (1, 12), 'additions': (1, 165), 'deletions': (0, 33), 'changed_files': (1, 11)}
# Filtered pull requests: 16
# {'contributions': (1, 280), 'followers': (8, 474), 'public_repos': (14, 396)}
# Pull Request Points: 1.822, 1.886, 1.637
# Contributor Points: 2.283, 2.166, 2.01
# Adding data to dataframe
# ------------------------------
# Processing jgh-/VideoCore-Inactive
# Number of pull request: 59
# Number of contributors: 14
# {'commits': (1, 21), 'additions': (0, 1321), 'deletions': (0, 2052478), 'changed_files': (1, 10398)}
# Filtered pull requests: 49
# {'contributions': (1, 364), 'followers': (0, 677), 'public_repos': (0, 3954)}
# Pull Request Points: 3.998, 4.502, 3.71
# Contributor Points: 1.611, 1.564, 1.612
# Adding data to dataframe
# ------------------------------
# Processing ammarahm-ed/react-native-mmkv-storage
# Number of pull request: 92
# Number of contributors: 40
# {'commits': (1, 143), 'additions': (0, 13153), 'deletions': (0, 14317), 'changed_files': (1, 109)}
# Filtered pull requests: 64
# {'contributions': (1, 712), 'followers': (0, 462), 'public_repos': (1, 225)}
# Pull Request Points: 2.689, 2.528, 3.042
# Contributor Points: 4.637, 4.286, 3.34
# Adding data to dataframe
# ------------------------------
# Processing martinus/robin-hood-hashing
# Number of pull request: 38
# Number of contributors: 17
# {'commits': (1, 9), 'additions': (1, 403), 'deletions': (0, 114), 'changed_files': (1, 10)}
# Filtered pull requests: 26
# {'contributions': (1, 834), 'followers': (1, 1410), 'public_repos': (7, 155)}
# Pull Request Points: 3.192, 3.218, 3.408
# Contributor Points: 2.362, 2.229, 1.816
# Adding data to dataframe
# ------------------------------
# Processing microsoft/DirectXMath
# Number of pull request: 34
# Number of contributors: 9
# {'commits': (1, 10), 'additions': (4, 1790), 'deletions': (0, 2396), 'changed_files': (1, 14)}
# Filtered pull requests: 26
# {'contributions': (1, 222), 'followers': (1, 1788), 'public_repos': (3, 252)}
# Pull Request Points: 3.543, 3.215, 3.552
# Contributor Points: 1.48, 1.436, 1.403
# Adding data to dataframe
# ------------------------------
# Processing InteractiveComputerGraphics/SPlisHSPlasH
# Number of pull request: 20
# Number of contributors: 8
# {'commits': (1, 19), 'additions': (1, 7462), 'deletions': (0, 143), 'changed_files': (1, 49)}
# Filtered pull requests: 18
# {'contributions': (1, 165), 'followers': (1, 168), 'public_repos': (0, 70)}
# Pull Request Points: 1.928, 1.818, 1.939
# Contributor Points: 1.849, 1.799, 1.69
# Adding data to dataframe
# ------------------------------
# Processing shamadee/web-dsp
# Number of pull request: 21
# Number of contributors: 4
# {'commits': (1, 5), 'additions': (0, 15494), 'deletions': (0, 4016), 'changed_files': (1, 19)}
# Filtered pull requests: 21
# {'contributions': (1, 36), 'followers': (21, 50), 'public_repos': (15, 70)}
# Pull Request Points: 2.274, 1.835, 2.125
# Contributor Points: 1.482, 1.507, 1.564
# Adding data to dataframe
# ------------------------------
# Processing stevemk14ebr/PolyHook_2_0
# Number of pull request: 83
# Number of contributors: 35
# {'commits': (1, 23), 'additions': (0, 3006), 'deletions': (0, 2709), 'changed_files': (1, 67)}
# Filtered pull requests: 79
# {'contributions': (1, 449), 'followers': (0, 673), 'public_repos': (0, 280)}
# Pull Request Points: 4.855, 4.223, 4.505
# Contributor Points: 3.805, 3.538, 3.078
# Adding data to dataframe
# ------------------------------
# Processing microsoft/snmalloc
# Number of pull request: 280
# Number of contributors: 29
# {'commits': (1, 44), 'additions': (0, 1820), 'deletions': (0, 494), 'changed_files': (1, 34)}
# Filtered pull requests: 248
# {'contributions': (1, 516), 'followers': (0, 4814), 'public_repos': (0, 286)}
# Pull Request Points: 18.007, 15.77, 18.883
# Contributor Points: 2.952, 2.877, 2.453
# Adding data to dataframe
# ------------------------------
